# %% [markdown]
# # Assignment: Implementing MADDPG with the TorchRL Toolkit
# In this task, you’ll implement the MADDPG algorithm — a method used to train multiple agents to learn and collaborate effectively.
#
# To make things smoother, we’ll be using TorchRL, a library that simplifies building and training RL agents.
#
# The assignment has two main goals:
#
# 1. Help you understand the key ideas behind MADDPG, especially the idea of centralized training (agents learn together) and decentralized execution (they act independently).
#
# 2. Introduce you to important TorchRL.
#
# We’ve already set up the basic structure for you. Your job is to complete the missing pieces marked as TODOs. Before each coding step, we’ll explain what the MADDPG concept is and how to apply it using the right TorchRL tools.

# %%
# Install dependencies
# !pip3 install torchrl
# !pip3 install vmas
# !pip3 install tqdm
# !apt-get update -y
# !apt-get install -y x11-utils xvfb python3-opengl libgl1-mesa-glx libglu1-mesa
# !pip install pyvirtualdisplay
# Out:
# Requirement already satisfied: torchrl in /usr/local/lib/python3.11/dist-packages (0.9.2)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from torchrl) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchrl) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from torchrl) (25.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from torchrl) (3.1.1)
# Requirement already satisfied: tensordict<0.10.0,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from torchrl) (0.9.1)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from tensordict<0.10.0,>=0.9.0->torchrl) (8.7.0)
# Requirement already satisfied: orjson in /usr/local/lib/python3.11/dist-packages (from tensordict<0.10.0,>=0.9.0->torchrl) (3.10.18)
# Requirement already satisfied: pyvers<0.2.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from tensordict<0.10.0,>=0.9.0->torchrl) (0.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->torchrl) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1.0->torchrl) (1.3.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchrl) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchrl) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchrl) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchrl) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchrl) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchrl) (2.4.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->tensordict<0.10.0,>=0.9.0->torchrl) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.1.0->torchrl) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchrl) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchrl) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchrl) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchrl) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchrl) (2024.2.0)
# Requirement already satisfied: vmas in /usr/local/lib/python3.11/dist-packages (1.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from vmas) (1.26.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from vmas) (2.6.0+cu124)
# Requirement already satisfied: pyglet<=1.5.27 in /usr/local/lib/python3.11/dist-packages (from vmas) (1.5.27)
# Requirement already satisfied: gym in /usr/local/lib/python3.11/dist-packages (from vmas) (0.25.2)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from vmas) (1.17.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym->vmas) (3.1.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym->vmas) (0.0.8)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->vmas) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->vmas) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->vmas) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->vmas) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->vmas) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->vmas) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->vmas) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->vmas) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->vmas) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->vmas) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->vmas) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->vmas) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->vmas) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->vmas) (2024.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,310 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,623 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,273 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,581 kB]
# Fetched 10.2 MB in 2s (4,575 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libglu1-mesa is already the newest version (9.0.2-1).
# x11-utils is already the newest version (7.7+5build2).
# python3-opengl is already the newest version (3.1.5+dfsg-1).
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.15).
# 0 upgraded, 0 newly installed, 0 to remove and 151 not upgraded.
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.11/dist-packages (3.0)

# %% [markdown]
# ##Imports

# %%
import copy
import tempfile
import torch
import torch.nn as nn
from matplotlib import pyplot as plt
import pyvirtualdisplay
from PIL import Image
import numpy as np

from tensordict import TensorDictBase
from tensordict.nn import TensorDictModule, TensorDictSequential
from torch import multiprocessing
from torchrl.collectors import SyncDataCollector
from torchrl.data import LazyMemmapStorage, RandomSampler, ReplayBuffer
from torchrl.envs import (
    check_env_specs,
    RewardSum,
    TransformedEnv,
    VmasEnv,
)
from torchrl.modules import (
    AdditiveGaussianModule,
    MLP,
    ProbabilisticActor,
    TanhDelta,
)
from torchrl.objectives import DDPGLoss, SoftUpdate, ValueEstimators
from tqdm import tqdm

# --- Setup Virtual Display ---
try:
    display = pyvirtualdisplay.Display(visible=False, size=(1400, 900))
    display.start()
    print("Virtual display started.")
except Exception as e:
    print(f"Could not start virtual display: {e}")
# Out:
# Virtual display started.

# %% [markdown]
# ##Configuration

# %%
# General
seed = 0
is_fork = multiprocessing.get_start_method() == "fork"
device = torch.device(0) if torch.cuda.is_available() and not is_fork else torch.device("cpu")
torch.manual_seed(seed)
print(f"Using device: {device}")

# Vmas Environment
scenario_name = "navigation"
n_agents = 3
max_steps = 100  # Episode steps before done

# Sampling
frames_per_batch = 2000
n_iters = 1500
total_frames = frames_per_batch * n_iters
num_vmas_envs = frames_per_batch // max_steps

# Replay Buffer
memory_size = 2_000_000

# Training
n_optimiser_steps = 10
train_batch_size = 512
lr = 3e-4
max_grad_norm = 1.0

# DDPG Algorithm
gamma = 0.99
polyak_tau = 0.005
# Out:
# Using device: cuda:0

# %% [markdown]
# ##Environment Setup

# %%
# Each agent is in its own group, so group_name == agent_name
custom_group_map = {f"agent_{i}": [f"agent_{i}"] for i in range(n_agents)}

# Create the vectorized Vmas environment
env = VmasEnv(
    scenario=scenario_name,
    num_envs=num_vmas_envs,
    continuous_actions=True,
    max_steps=max_steps,
    device=device,
    n_agents=n_agents,
    group_map=custom_group_map,
)

# Wrap the environment to sum rewards for each agent group
env = TransformedEnv(
    env,
    RewardSum(
        in_keys=env.reward_keys,
        reset_keys=["_reset"] * len(env.group_map.keys()),
    ),
)

# Print environment specs
print(f"group_map: {env.group_map}")
print("action_spec:", env.full_action_spec)
print("reward_spec:", env.full_reward_spec)
print("done_spec:", env.full_done_spec)
print("observation_spec:", env.observation_spec)

check_env_specs(env)
# Out:
# group_map: {'agent_0': ['agent_0'], 'agent_1': ['agent_1'], 'agent_2': ['agent_2']}
# action_spec: Composite(
#     agent_0: Composite(
#         action: BoundedContinuous(
#             shape=torch.Size([20, 1, 2]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([20, 1, 2]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([20, 1, 2]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         device=cuda:0,
#         shape=torch.Size([20, 1]),
#         data_cls=None),
#     agent_1: Composite(
#         action: BoundedContinuous(
#             shape=torch.Size([20, 1, 2]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([20, 1, 2]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([20, 1, 2]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         device=cuda:0,
#         shape=torch.Size([20, 1]),
#         data_cls=None),
#     agent_2: Composite(
#         action: BoundedContinuous(
#             shape=torch.Size([20, 1, 2]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([20, 1, 2]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([20, 1, 2]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         device=cuda:0,
#         shape=torch.Size([20, 1]),
#         data_cls=None),
#     device=cuda:0,
#     shape=torch.Size([20]),
#     data_cls=None)
# reward_spec: Composite(
#     agent_0: Composite(
#         reward: UnboundedContinuous(
#             shape=torch.Size([20, 1, 1]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         device=cuda:0,
#         shape=torch.Size([20, 1]),
#         data_cls=None),
#     agent_1: Composite(
#         reward: UnboundedContinuous(
#             shape=torch.Size([20, 1, 1]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         device=cuda:0,
#         shape=torch.Size([20, 1]),
#         data_cls=None),
#     agent_2: Composite(
#         reward: UnboundedContinuous(
#             shape=torch.Size([20, 1, 1]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         device=cuda:0,
#         shape=torch.Size([20, 1]),
#         data_cls=None),
#     device=cuda:0,
#     shape=torch.Size([20]),
#     data_cls=None)
# done_spec: Composite(
#     done: Categorical(
#         shape=torch.Size([20, 1]),
#         space=CategoricalBox(n=2),
#         device=cuda:0,
#         dtype=torch.bool,
#         domain=discrete),
#     terminated: Categorical(
#         shape=torch.Size([20, 1]),
#         space=CategoricalBox(n=2),
#         device=cuda:0,
#         dtype=torch.bool,
#         domain=discrete),
#     device=cuda:0,
#     shape=torch.Size([20]),
#     data_cls=None)
# observation_spec: Composite(
#     agent_0: Composite(
#         observation: UnboundedContinuous(
#             shape=torch.Size([20, 1, 18]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([20, 1, 18]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([20, 1, 18]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         info: Composite(
#             pos_rew: UnboundedContinuous(
#                 shape=torch.Size([20, 1, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#                 device=cuda:0,
#                 dtype=torch.float32,
#                 domain=continuous),
#             final_rew: UnboundedContinuous(
#                 shape=torch.Size([20, 1, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#                 device=cuda:0,
#                 dtype=torch.float32,
#                 domain=continuous),
#             agent_collisions: UnboundedContinuous(
#                 shape=torch.Size([20, 1, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#                 device=cuda:0,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cuda:0,
#             shape=torch.Size([20, 1]),
#             data_cls=None),
#         episode_reward: UnboundedContinuous(
#             shape=torch.Size([20, 1, 1]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         device=cuda:0,
#         shape=torch.Size([20, 1]),
#         data_cls=None),
#     agent_1: Composite(
#         observation: UnboundedContinuous(
#             shape=torch.Size([20, 1, 18]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([20, 1, 18]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([20, 1, 18]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         info: Composite(
#             pos_rew: UnboundedContinuous(
#                 shape=torch.Size([20, 1, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#                 device=cuda:0,
#                 dtype=torch.float32,
#                 domain=continuous),
#             final_rew: UnboundedContinuous(
#                 shape=torch.Size([20, 1, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#                 device=cuda:0,
#                 dtype=torch.float32,
#                 domain=continuous),
#             agent_collisions: UnboundedContinuous(
#                 shape=torch.Size([20, 1, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#                 device=cuda:0,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cuda:0,
#             shape=torch.Size([20, 1]),
#             data_cls=None),
#         episode_reward: UnboundedContinuous(
#             shape=torch.Size([20, 1, 1]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         device=cuda:0,
#         shape=torch.Size([20, 1]),
#         data_cls=None),
#     agent_2: Composite(
#         observation: UnboundedContinuous(
#             shape=torch.Size([20, 1, 18]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([20, 1, 18]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([20, 1, 18]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         info: Composite(
#             pos_rew: UnboundedContinuous(
#                 shape=torch.Size([20, 1, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#                 device=cuda:0,
#                 dtype=torch.float32,
#                 domain=continuous),
#             final_rew: UnboundedContinuous(
#                 shape=torch.Size([20, 1, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#                 device=cuda:0,
#                 dtype=torch.float32,
#                 domain=continuous),
#             agent_collisions: UnboundedContinuous(
#                 shape=torch.Size([20, 1, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#                 device=cuda:0,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cuda:0,
#             shape=torch.Size([20, 1]),
#             data_cls=None),
#         episode_reward: UnboundedContinuous(
#             shape=torch.Size([20, 1, 1]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([20, 1, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         device=cuda:0,
#         shape=torch.Size([20, 1]),
#         data_cls=None),
#     device=cuda:0,
#     shape=torch.Size([20]),
#     data_cls=None)
# 2025-09-10 19:03:18,057 [torchrl][INFO]    check_env_specs succeeded! [END]

# %% [markdown]
# ##Part 1 : Decentralized Actor
#
# **1a. MADDPG Concept: The Agent's Brain**
#
# In MADDPG, each agent has its own independent "actor" network. This network takes the agent's observation and decides which action to take. It's the "decentralized execution" part of the algorithm.
#
# Your Task:
#
# Implement the Actor Network using torchrl.modules.MLP. This will be a standard PyTorch nn.Module that serves as the brain for a single agent.
#
# **1b. TorchRL vs TensorDictModule**
#
# A standard nn.Module doesn't know how to interact with TorchRL's data structures. We need to wrap it with a TensorDictModule. This wrapper acts as an adapter, telling your MLP which data "key" to read its input from in the TensorDict and which "key" to write its output to.
#
# Your Task:
#
# Wrap your AgentMLP in a TensorDictModule.

# %% [markdown]
# ##Policy Initialization

# %%
# Part 1: Create the Actor Network using torchrl.modules.MLP
policy_modules = {}
for group, agents in env.group_map.items():
    agent_modules = {}
    for agent in agents:
        agent_spec = env.observation_spec[agent, "observation"]
        action_spec = env.full_action_spec[agent, "action"]
        agent_modules[agent] = MLP(
            in_features=agent_spec.shape[-1],
            out_features=action_spec.shape[-1],
            num_cells=[256, 256],
            activation_class=nn.ReLU,
        ).to(device)

    agent_policy_modules = {}
    for agent in agents:
        agent_policy_modules[agent] = TensorDictModule(
            module=agent_modules[agent],
            in_keys=[(agent, "observation")],
            out_keys=[(agent, "param")],
        )
    policy_modules[group] = TensorDictSequential(*agent_policy_modules.values())


# Create Probabilistic Policies
policies = {}
for group, agents in env.group_map.items():
    agent_policies = []
    for agent in agents:
        agent_policies.append(
            ProbabilisticActor(
                module=policy_modules[group],
                spec=env.full_action_spec[agent, "action"],
                in_keys=[(agent, "param")],
                out_keys=[(agent, "action")],
                distribution_class=TanhDelta,
                distribution_kwargs={
                    "low": env.full_action_spec_unbatched[agent, "action"].space.low,
                    "high": env.full_action_spec_unbatched[agent, "action"].space.high,
                },
                return_log_prob=False,
            )
        )
    policies[group] = TensorDictSequential(*agent_policies)

# Create Target Policies for DDPG
target_policies = copy.deepcopy(policies)

# Create Exploration Policies: An AdditiveGaussianModule is appended to the policy to add noise for exploration
exploration_policies = {}
for group, _agents in env.group_map.items():
    first_actor = None
    for module in policies[group].modules():
        if isinstance(module, ProbabilisticActor):
            first_actor = module
            break
    if first_actor is None:
        raise RuntimeError("No ProbabilisticActor found in policies[group]")

    exploration_policy = TensorDictSequential(
        policies[group],
        AdditiveGaussianModule(
            spec=first_actor.spec,
            annealing_num_steps=total_frames // 3,
            action_key=(group, "action"),
            sigma_init=0.5,
            sigma_end=0.05,
        ),
    )
    exploration_policies[group] = exploration_policy

# %% [markdown]
# ##Part 2: The Centralized Critic
#
# **2a. MADDPG Concept: Using Global Information**
#
# One of the key strengths of the MADDPG algorithm lies in its use of a centralized critic during training. Unlike the decentralized actors, which only have access to their individual observations, the centralized critic has access to the observations and actions of all agents. This broader perspective enables it to more accurately evaluate the quality of joint actions taken by the agents, which in turn leads to more stable and cooperative learning dynamics.
#
# Your task:
#
# Implement the CentralizedCritic using torchrl.modules.MLP. This network takes observations and actions of all agents, and return a scalar value representing the estimated state-action value. It's the "centralized training" part of the algorithm.
#
# **2b. TorchRL Tool: Assembling Inputs with TensorDictModule**
#
# How do we collect data from many different keys and feed it as one tensor to our critic? TensorDictModule can do more than just wrap a network; it can also perform operations. We can give it a list of in_keys and a lambda function to tell it how to combine them.
#
# Your Task:
#
# Create a TensorDictModule that gathers all observations and actions and concatenates them into a single tensor for the critic.

# %% [markdown]
# ##Critic Network Initialization

# %%
# Part 2: Create the Centralized Critic using torchrl.modules.MLP
critics = {}
for group, agents in env.group_map.items():
    agent_critic_modules = {}
    for agent in agents:
        # Calculate the total input features for the centralized critic
        critic_in_features = sum(
            env.observation_spec[a, "observation"].shape[-1] for a in agents
        ) + sum(env.full_action_spec[a, "action"].shape[-1] for a in agents)

        agent_critic_modules[agent] = MLP(
            in_features=critic_in_features,
            out_features=1,
            num_cells=[256, 256],
            activation_class=nn.ReLU,
        ).to(device)
        
    agent_critic_tdmodules = {}
    for agent in agents:
        # 1. Define the `cat_inputs` list for concatenation.
        cat_inputs = [] # Fill this list
        for a in agents:
            cat_inputs.append((a, "observation"))
            cat_inputs.append((a, "action"))

        # 2. Create the cat_module using TensorDictModule and a lambda function
        cat_module = TensorDictModule(
            module=lambda *inputs: torch.cat(inputs, dim=-1),
            in_keys=cat_inputs,
            out_keys=[(agent, "obs_actions")],
        )

        critic_module = TensorDictModule(
            agent_critic_modules[agent],
            in_keys=[(agent, "obs_actions")], # Must match cat_module's out_key
            out_keys=[(agent, "state_action_value")],
        )
        agent_critic_tdmodules[agent] = TensorDictSequential(cat_module, critic_module)
    critics[group] = TensorDictSequential(*agent_critic_tdmodules.values())

print("Model and policy structure ready for review.")
# Out:
# Model and policy structure ready for review.

# %% [markdown]
# ##Part 3: The Learning Algorithm
#
# **3a. MADDPG Concept: The Update Step**
#
# The critic learns by comparing its Q-value prediction to a "target" value calculated from the reward and the next state's value. The actor then learns by performing gradient ascent to find actions that the critic scores highly.
#
# **3b. TorchRL Tool: DDPGLoss**
#
# This high-level module encapsulates the entire loss calculation for both the actor and the critic. You provide your networks, and it computes the gradients. Your only job is to tell it which keys to use for its calculations. You must also supply the actions from the target policies, as these are used to calculate the target Q-value, which is a key part of the DDPG algorithm.
#
# Your Task:
#
# 1.   Configure the DDPGLoss module with the correct keys.
# 2.   In the main training loop, provide the target actions needed for the loss calculation.

# %% [markdown]
# ##Replay Buffer, Losses, and Optimizers

# %%
# Part 3
# Shared Replay Buffer
shared_replay_buffer = ReplayBuffer(
    storage=LazyMemmapStorage(memory_size, scratch_dir=tempfile.TemporaryDirectory().name),
    sampler=RandomSampler(),
    batch_size=train_batch_size,
)
if device.type != "cpu":
    shared_replay_buffer.append_transform(lambda x: x.to(device))

# DDPG Losses
losses = {}
for group, _agents in env.group_map.items():
    loss_module = DDPGLoss(
        actor_network=policies[group],
        value_network=critics[group],
        delay_value=True,
        delay_actor=True,
        loss_function="l2",
    )
    
    loss_module.set_keys(
        reward=(group, "reward"),
        done=(group, "done"),
        terminated=(group, "terminated"),
        state_action_value=(group, "state_action_value"),
    )
    
    loss_module.make_value_estimator(ValueEstimators.TD0, gamma=gamma)
    losses[group] = loss_module

# Target Network Updaters and Optimizers
target_updaters = {group: SoftUpdate(loss, tau=polyak_tau) for group, loss in losses.items()}
optimisers = {
    group: {
        "loss_actor": torch.optim.Adam(loss.actor_network_params.flatten_keys().values(), lr=1e-4),
        "loss_value": torch.optim.Adam(loss.value_network_params.flatten_keys().values(), lr=3e-4),
    }
    for group, loss in losses.items()
}
print("Losses, optimizers, and replay buffer are ready.")
# Out:
# Losses, optimizers, and replay buffer are ready.

# %% [markdown]
# ##Data Collection and Training

# %%
# Data Collection and Training
collector = SyncDataCollector(
    env,
    TensorDictSequential(*exploration_policies.values()),
    device=device,
    frames_per_batch=frames_per_batch,
    total_frames=total_frames,
)


def process_batch(batch: TensorDictBase) -> TensorDictBase:
    for group in env.group_map.keys():
        keys = list(batch.keys(True, True))
        group_shape = batch.get_item_shape(group)
        nested_done_key = ("next", group, "done")
        nested_terminated_key = ("next", group, "terminated")
        if nested_done_key not in keys:
            batch.set(
                nested_done_key,
                batch.get(("next", "done")).unsqueeze(-1).expand((*group_shape, 1)),
            )
        if nested_terminated_key not in keys:
            batch.set(
                nested_terminated_key,
                batch.get(("next", "terminated"))
                .unsqueeze(-1)
                .expand((*group_shape, 1)),
            )
    return batch

# Training Loop
episode_reward_mean_map = {group: [] for group in env.group_map.keys()}
pbar = tqdm(total=n_iters, desc="Training Progress")

for iteration, batch in enumerate(collector):
    current_frames = batch.numel()
    batch = process_batch(batch)
    shared_replay_buffer.extend(batch.reshape(-1))

    for group in env.group_map.keys():
        for _ in range(n_optimiser_steps):
            subdata = shared_replay_buffer.sample()

            # --- Part 3b: Compute Target Actions for the Critic's Loss ---
            with torch.no_grad():
                next_td = subdata.get("next").to(device)
                for other_group, target_policy in target_policies.items():
                    target_policy(next_td) # This modifies next_td in-place
                    subdata.set(("next", other_group, "action"), next_td.get((other_group, "action")))

            loss_vals = losses[group](subdata)
            for loss_name in ["loss_actor", "loss_value"]:
                loss = loss_vals[loss_name]
                optimiser = optimisers[group][loss_name]
                loss.backward()
                params = optimiser.param_groups[0]["params"]
                torch.nn.utils.clip_grad_norm_(params, max_grad_norm)
                optimiser.step()
                optimiser.zero_grad()
            target_updaters[group].step()
        exploration_policies[group][-1].step(current_frames)

    for group in env.group_map.keys():
        episode_reward_mean = (
            batch.get(("next", group, "episode_reward"))[
                batch.get(("next", group, "done"))
            ]
            .mean()
            .item()
        )
        episode_reward_mean_map[group].append(episode_reward_mean)

    reward_strings = [
        f"{group}: {episode_reward_mean_map[group][-1]:.2f}"
        for group in env.group_map.keys()
    ]
    description = (
        f"Iter [{iteration+1}/{n_iters}] | Rewards: " + " | ".join(reward_strings)
    )
    pbar.set_description(description)
    pbar.refresh()

pbar.close()
collector.shutdown()
print("\nTraining finished.")
# Out:
# Training Progress:   0%|          | 0/1500 [1:25:41<?, ?it/s]A
#
# Iter [1/1500] | Rewards: agent_0: -0.22 | agent_1: -0.22 | agent_2: -0.22:   0%|          | 0/1500 [00:02<?, ?it/s]
# Iter [1/1500] | Rewards: agent_0: -0.22 | agent_1: -0.22 | agent_2: -0.22:   0%|          | 0/1500 [00:02<?, ?it/s]
# Iter [2/1500] | Rewards: agent_0: -0.57 | agent_1: -0.87 | agent_2: -0.32:   0%|          | 0/1500 [00:04<?, ?it/s]
# Iter [2/1500] | Rewards: agent_0: -0.57 | agent_1: -0.87 | agent_2: -0.32:   0%|          | 0/1500 [00:04<?, ?it/s]
# Iter [3/1500] | Rewards: agent_0: -0.45 | agent_1: -0.35 | agent_2: -0.85:   0%|          | 0/1500 [00:06<?, ?it/s]
# Iter [3/1500] | Rewards: agent_0: -0.45 | agent_1: -0.35 | agent_2: -0.85:   0%|          | 0/1500 [00:06<?, ?it/s]
# Iter [4/1500] | Rewards: agent_0: -0.03 | agent_1: 0.12 | agent_2: -0.13:   0%|          | 0/1500 [00:08<?, ?it/s]
# Iter [4/1500] | Rewards: agent_0: -0.03 | agent_1: 0.12 | agent_2: -0.13:   0%|          | 0/1500 [00:08<?, ?it/s]
# Iter [5/1500] | Rewards: agent_0: 0.11 | agent_1: 0.01 | agent_2: 0.21:   0%|          | 0/1500 [00:10<?, ?it/s]
# Iter [5/1500] | Rewards: agent_0: 0.11 | agent_1: 0.01 | agent_2: 0.21:   0%|          | 0/1500 [00:10<?, ?it/s]
# Iter [6/1500] | Rewards: agent_0: -2.69 | agent_1: -1.19 | agent_2: -1.69:   0%|          | 0/1500 [00:12<?, ?it/s]
# Iter [6/1500] | Rewards: agent_0: -2.69 | agent_1: -1.19 | agent_2: -1.69:   0%|          | 0/1500 [00:12<?, ?it/s]
# Iter [7/1500] | Rewards: agent_0: -0.40 | agent_1: -0.40 | agent_2: -0.65:   0%|          | 0/1500 [00:14<?, ?it/s]
# Iter [7/1500] | Rewards: agent_0: -0.40 | agent_1: -0.40 | agent_2: -0.65:   0%|          | 0/1500 [00:14<?, ?it/s]
# Iter [8/1500] | Rewards: agent_0: -0.06 | agent_1: -0.26 | agent_2: -0.01:   0%|          | 0/1500 [00:16<?, ?it/s]
# Iter [8/1500] | Rewards: agent_0: -0.06 | agent_1: -0.26 | agent_2: -0.01:   0%|          | 0/1500 [00:16<?, ?it/s]
# Iter [9/1500] | Rewards: agent_0: -0.75 | agent_1: -2.70 | agent_2: -3.45:   0%|          | 0/1500 [00:18<?, ?it/s]
# Iter [9/1500] | Rewards: agent_0: -0.75 | agent_1: -2.70 | agent_2: -3.45:   0%|          | 0/1500 [00:18<?, ?it/s]
# Iter [10/1500] | Rewards: agent_0: -0.50 | agent_1: -0.70 | agent_2: 0.70:   0%|          | 0/1500 [00:20<?, ?it/s]
# Iter [10/1500] | Rewards: agent_0: -0.50 | agent_1: -0.70 | agent_2: 0.70:   0%|          | 0/1500 [00:20<?, ?it/s]
# Iter [11/1500] | Rewards: agent_0: -0.43 | agent_1: 0.37 | agent_2: -0.68:   0%|          | 0/1500 [00:22<?, ?it/s]
# Iter [11/1500] | Rewards: agent_0: -0.43 | agent_1: 0.37 | agent_2: -0.68:   0%|          | 0/1500 [00:22<?, ?it/s]
# Iter [12/1500] | Rewards: agent_0: -1.94 | agent_1: 0.06 | agent_2: -1.39:   0%|          | 0/1500 [00:25<?, ?it/s]
# Iter [12/1500] | Rewards: agent_0: -1.94 | agent_1: 0.06 | agent_2: -1.39:   0%|          | 0/1500 [00:25<?, ?it/s]
# Iter [13/1500] | Rewards: agent_0: -0.27 | agent_1: -0.07 | agent_2: 0.68:   0%|          | 0/1500 [00:27<?, ?it/s]
# Iter [13/1500] | Rewards: agent_0: -0.27 | agent_1: -0.07 | agent_2: 0.68:   0%|          | 0/1500 [00:27<?, ?it/s]
# Iter [14/1500] | Rewards: agent_0: -1.14 | agent_1: -0.24 | agent_2: -0.39:   0%|          | 0/1500 [00:29<?, ?it/s]
# Iter [14/1500] | Rewards: agent_0: -1.14 | agent_1: -0.24 | agent_2: -0.39:   0%|          | 0/1500 [00:29<?, ?it/s]
# Iter [15/1500] | Rewards: agent_0: -3.51 | agent_1: -0.56 | agent_2: -2.51:   0%|          | 0/1500 [00:31<?, ?it/s]
# Iter [15/1500] | Rewards: agent_0: -3.51 | agent_1: -0.56 | agent_2: -2.51:   0%|          | 0/1500 [00:31<?, ?it/s]
# Iter [16/1500] | Rewards: agent_0: 0.22 | agent_1: -0.53 | agent_2: -0.78:   0%|          | 0/1500 [00:33<?, ?it/s]
# Iter [16/1500] | Rewards: agent_0: 0.22 | agent_1: -0.53 | agent_2: -0.78:   0%|          | 0/1500 [00:33<?, ?it/s]
# Iter [17/1500] | Rewards: agent_0: 0.03 | agent_1: 1.23 | agent_2: 0.03:   0%|          | 0/1500 [00:35<?, ?it/s]
# Iter [17/1500] | Rewards: agent_0: 0.03 | agent_1: 1.23 | agent_2: 0.03:   0%|          | 0/1500 [00:35<?, ?it/s]
# Iter [18/1500] | Rewards: agent_0: -1.84 | agent_1: -0.59 | agent_2: -2.19:   0%|          | 0/1500 [00:37<?, ?it/s]
# Iter [18/1500] | Rewards: agent_0: -1.84 | agent_1: -0.59 | agent_2: -2.19:   0%|          | 0/1500 [00:37<?, ?it/s]
# Iter [19/1500] | Rewards: agent_0: 0.34 | agent_1: -0.31 | agent_2: 0.29:   0%|          | 0/1500 [00:39<?, ?it/s]
# Iter [19/1500] | Rewards: agent_0: 0.34 | agent_1: -0.31 | agent_2: 0.29:   0%|          | 0/1500 [00:39<?, ?it/s]
# Iter [20/1500] | Rewards: agent_0: -0.69 | agent_1: -0.29 | agent_2: 0.46:   0%|          | 0/1500 [00:41<?, ?it/s]
# Iter [20/1500] | Rewards: agent_0: -0.69 | agent_1: -0.29 | agent_2: 0.46:   0%|          | 0/1500 [00:41<?, ?it/s]
# Iter [21/1500] | Rewards: agent_0: -0.84 | agent_1: -0.84 | agent_2: -0.89:   0%|          | 0/1500 [00:43<?, ?it/s]
# Iter [21/1500] | Rewards: agent_0: -0.84 | agent_1: -0.84 | agent_2: -0.89:   0%|          | 0/1500 [00:43<?, ?it/s]
# Iter [22/1500] | Rewards: agent_0: -0.05 | agent_1: -0.25 | agent_2: -0.45:   0%|          | 0/1500 [00:45<?, ?it/s]
# Iter [22/1500] | Rewards: agent_0: -0.05 | agent_1: -0.25 | agent_2: -0.45:   0%|          | 0/1500 [00:45<?, ?it/s]
# Iter [23/1500] | Rewards: agent_0: 0.14 | agent_1: -0.46 | agent_2: -0.46:   0%|          | 0/1500 [00:48<?, ?it/s]
# Iter [23/1500] | Rewards: agent_0: 0.14 | agent_1: -0.46 | agent_2: -0.46:   0%|          | 0/1500 [00:48<?, ?it/s]
# Iter [24/1500] | Rewards: agent_0: -2.98 | agent_1: -3.08 | agent_2: -0.78:   0%|          | 0/1500 [00:50<?, ?it/s]
# Iter [24/1500] | Rewards: agent_0: -2.98 | agent_1: -3.08 | agent_2: -0.78:   0%|          | 0/1500 [00:50<?, ?it/s]
# Iter [25/1500] | Rewards: agent_0: -0.62 | agent_1: -0.47 | agent_2: -0.87:   0%|          | 0/1500 [00:52<?, ?it/s]
# Iter [25/1500] | Rewards: agent_0: -0.62 | agent_1: -0.47 | agent_2: -0.87:   0%|          | 0/1500 [00:52<?, ?it/s]
# Iter [26/1500] | Rewards: agent_0: -1.97 | agent_1: -1.97 | agent_2: -0.72:   0%|          | 0/1500 [00:54<?, ?it/s]
# Iter [26/1500] | Rewards: agent_0: -1.97 | agent_1: -1.97 | agent_2: -0.72:   0%|          | 0/1500 [00:54<?, ?it/s]
# Iter [27/1500] | Rewards: agent_0: -1.13 | agent_1: -0.63 | agent_2: -0.93:   0%|          | 0/1500 [00:56<?, ?it/s]
# Iter [27/1500] | Rewards: agent_0: -1.13 | agent_1: -0.63 | agent_2: -0.93:   0%|          | 0/1500 [00:56<?, ?it/s]
# Iter [28/1500] | Rewards: agent_0: -3.28 | agent_1: -3.23 | agent_2: -1.83:   0%|          | 0/1500 [00:58<?, ?it/s]
# Iter [28/1500] | Rewards: agent_0: -3.28 | agent_1: -3.23 | agent_2: -1.83:   0%|          | 0/1500 [00:58<?, ?it/s]
# Iter [29/1500] | Rewards: agent_0: -0.07 | agent_1: -0.22 | agent_2: -0.37:   0%|          | 0/1500 [01:00<?, ?it/s]
# Iter [29/1500] | Rewards: agent_0: -0.07 | agent_1: -0.22 | agent_2: -0.37:   0%|          | 0/1500 [01:00<?, ?it/s]
# Iter [30/1500] | Rewards: agent_0: -0.69 | agent_1: -1.04 | agent_2: -1.49:   0%|          | 0/1500 [01:02<?, ?it/s]
# Iter [30/1500] | Rewards: agent_0: -0.69 | agent_1: -1.04 | agent_2: -1.49:   0%|          | 0/1500 [01:02<?, ?it/s]
# Iter [31/1500] | Rewards: agent_0: -1.27 | agent_1: -2.62 | agent_2: -2.47:   0%|          | 0/1500 [01:04<?, ?it/s]
# Iter [31/1500] | Rewards: agent_0: -1.27 | agent_1: -2.62 | agent_2: -2.47:   0%|          | 0/1500 [01:04<?, ?it/s]
# Iter [32/1500] | Rewards: agent_0: -1.65 | agent_1: -2.75 | agent_2: -1.80:   0%|          | 0/1500 [01:06<?, ?it/s]
# Iter [32/1500] | Rewards: agent_0: -1.65 | agent_1: -2.75 | agent_2: -1.80:   0%|          | 0/1500 [01:06<?, ?it/s]
# Iter [33/1500] | Rewards: agent_0: -1.35 | agent_1: -0.15 | agent_2: -1.15:   0%|          | 0/1500 [01:09<?, ?it/s]
# Iter [33/1500] | Rewards: agent_0: -1.35 | agent_1: -0.15 | agent_2: -1.15:   0%|          | 0/1500 [01:09<?, ?it/s]
# Iter [34/1500] | Rewards: agent_0: -1.64 | agent_1: -1.29 | agent_2: -1.54:   0%|          | 0/1500 [01:11<?, ?it/s]
# Iter [34/1500] | Rewards: agent_0: -1.64 | agent_1: -1.29 | agent_2: -1.54:   0%|          | 0/1500 [01:11<?, ?it/s]
# Iter [35/1500] | Rewards: agent_0: -1.33 | agent_1: -0.73 | agent_2: -0.88:   0%|          | 0/1500 [01:13<?, ?it/s]
# Iter [35/1500] | Rewards: agent_0: -1.33 | agent_1: -0.73 | agent_2: -0.88:   0%|          | 0/1500 [01:13<?, ?it/s]
# Iter [36/1500] | Rewards: agent_0: -3.19 | agent_1: -1.89 | agent_2: -1.64:   0%|          | 0/1500 [01:15<?, ?it/s]
# Iter [36/1500] | Rewards: agent_0: -3.19 | agent_1: -1.89 | agent_2: -1.64:   0%|          | 0/1500 [01:15<?, ?it/s]
# Iter [37/1500] | Rewards: agent_0: -1.57 | agent_1: -1.02 | agent_2: -0.92:   0%|          | 0/1500 [01:17<?, ?it/s]
# Iter [37/1500] | Rewards: agent_0: -1.57 | agent_1: -1.02 | agent_2: -0.92:   0%|          | 0/1500 [01:17<?, ?it/s]
# Iter [38/1500] | Rewards: agent_0: -0.47 | agent_1: -0.47 | agent_2: -0.37:   0%|          | 0/1500 [01:19<?, ?it/s]
# Iter [38/1500] | Rewards: agent_0: -0.47 | agent_1: -0.47 | agent_2: -0.37:   0%|          | 0/1500 [01:19<?, ?it/s]
# Iter [39/1500] | Rewards: agent_0: -3.19 | agent_1: -1.19 | agent_2: -1.49:   0%|          | 0/1500 [01:21<?, ?it/s]
# Iter [39/1500] | Rewards: agent_0: -3.19 | agent_1: -1.19 | agent_2: -1.49:   0%|          | 0/1500 [01:21<?, ?it/s]
# Iter [40/1500] | Rewards: agent_0: 0.35 | agent_1: -0.30 | agent_2: 0.10:   0%|          | 0/1500 [01:23<?, ?it/s]
# Iter [40/1500] | Rewards: agent_0: 0.35 | agent_1: -0.30 | agent_2: 0.10:   0%|          | 0/1500 [01:23<?, ?it/s]
# Iter [41/1500] | Rewards: agent_0: 0.80 | agent_1: 0.55 | agent_2: 0.55:   0%|          | 0/1500 [01:25<?, ?it/s]
# Iter [41/1500] | Rewards: agent_0: 0.80 | agent_1: 0.55 | agent_2: 0.55:   0%|          | 0/1500 [01:25<?, ?it/s]
# Iter [42/1500] | Rewards: agent_0: -1.02 | agent_1: -1.02 | agent_2: 0.53:   0%|          | 0/1500 [01:27<?, ?it/s]
# Iter [42/1500] | Rewards: agent_0: -1.02 | agent_1: -1.02 | agent_2: 0.53:   0%|          | 0/1500 [01:27<?, ?it/s]
# Iter [43/1500] | Rewards: agent_0: -1.43 | agent_1: -0.58 | agent_2: -1.38:   0%|          | 0/1500 [01:30<?, ?it/s]
# Iter [43/1500] | Rewards: agent_0: -1.43 | agent_1: -0.58 | agent_2: -1.38:   0%|          | 0/1500 [01:30<?, ?it/s]
# Iter [44/1500] | Rewards: agent_0: -0.86 | agent_1: -1.11 | agent_2: 0.29:   0%|          | 0/1500 [01:32<?, ?it/s]
# Iter [44/1500] | Rewards: agent_0: -0.86 | agent_1: -1.11 | agent_2: 0.29:   0%|          | 0/1500 [01:32<?, ?it/s]
# Iter [45/1500] | Rewards: agent_0: -0.84 | agent_1: -1.84 | agent_2: -0.94:   0%|          | 0/1500 [01:34<?, ?it/s]
# Iter [45/1500] | Rewards: agent_0: -0.84 | agent_1: -1.84 | agent_2: -0.94:   0%|          | 0/1500 [01:34<?, ?it/s]
# Iter [46/1500] | Rewards: agent_0: -0.45 | agent_1: -0.35 | agent_2: -0.20:   0%|          | 0/1500 [01:36<?, ?it/s]
# Iter [46/1500] | Rewards: agent_0: -0.45 | agent_1: -0.35 | agent_2: -0.20:   0%|          | 0/1500 [01:36<?, ?it/s]
# Iter [47/1500] | Rewards: agent_0: -1.08 | agent_1: -1.58 | agent_2: -0.78:   0%|          | 0/1500 [01:38<?, ?it/s]
# Iter [47/1500] | Rewards: agent_0: -1.08 | agent_1: -1.58 | agent_2: -0.78:   0%|          | 0/1500 [01:38<?, ?it/s]
# Iter [48/1500] | Rewards: agent_0: -0.13 | agent_1: -0.68 | agent_2: -0.58:   0%|          | 0/1500 [01:40<?, ?it/s]
# Iter [48/1500] | Rewards: agent_0: -0.13 | agent_1: -0.68 | agent_2: -0.58:   0%|          | 0/1500 [01:40<?, ?it/s]
# Iter [49/1500] | Rewards: agent_0: 0.32 | agent_1: 0.07 | agent_2: 0.27:   0%|          | 0/1500 [01:42<?, ?it/s]
# Iter [49/1500] | Rewards: agent_0: 0.32 | agent_1: 0.07 | agent_2: 0.27:   0%|          | 0/1500 [01:42<?, ?it/s]
# Iter [50/1500] | Rewards: agent_0: 0.35 | agent_1: 0.70 | agent_2: 0.45:   0%|          | 0/1500 [01:44<?, ?it/s]
# Iter [50/1500] | Rewards: agent_0: 0.35 | agent_1: 0.70 | agent_2: 0.45:   0%|          | 0/1500 [01:44<?, ?it/s]
# Iter [51/1500] | Rewards: agent_0: -3.09 | agent_1: -1.49 | agent_2: -0.74:   0%|          | 0/1500 [01:46<?, ?it/s]
# Iter [51/1500] | Rewards: agent_0: -3.09 | agent_1: -1.49 | agent_2: -0.74:   0%|          | 0/1500 [01:46<?, ?it/s]
# Iter [52/1500] | Rewards: agent_0: -0.75 | agent_1: -0.75 | agent_2: 0.35:   0%|          | 0/1500 [01:48<?, ?it/s]
# Iter [52/1500] | Rewards: agent_0: -0.75 | agent_1: -0.75 | agent_2: 0.35:   0%|          | 0/1500 [01:48<?, ?it/s]
# Iter [53/1500] | Rewards: agent_0: -0.28 | agent_1: -0.18 | agent_2: 0.57:   0%|          | 0/1500 [01:50<?, ?it/s]
# Iter [53/1500] | Rewards: agent_0: -0.28 | agent_1: -0.18 | agent_2: 0.57:   0%|          | 0/1500 [01:50<?, ?it/s]
# Iter [54/1500] | Rewards: agent_0: -0.67 | agent_1: -1.02 | agent_2: 0.38:   0%|          | 0/1500 [01:53<?, ?it/s]
# Iter [54/1500] | Rewards: agent_0: -0.67 | agent_1: -1.02 | agent_2: 0.38:   0%|          | 0/1500 [01:53<?, ?it/s]
# Iter [55/1500] | Rewards: agent_0: 0.18 | agent_1: 0.83 | agent_2: 0.38:   0%|          | 0/1500 [01:55<?, ?it/s]
# Iter [55/1500] | Rewards: agent_0: 0.18 | agent_1: 0.83 | agent_2: 0.38:   0%|          | 0/1500 [01:55<?, ?it/s]
# Iter [56/1500] | Rewards: agent_0: 0.43 | agent_1: 0.13 | agent_2: -0.07:   0%|          | 0/1500 [01:57<?, ?it/s]
# Iter [56/1500] | Rewards: agent_0: 0.43 | agent_1: 0.13 | agent_2: -0.07:   0%|          | 0/1500 [01:57<?, ?it/s]
# Iter [57/1500] | Rewards: agent_0: 1.13 | agent_1: 0.48 | agent_2: 0.78:   0%|          | 0/1500 [01:59<?, ?it/s]
# Iter [57/1500] | Rewards: agent_0: 1.13 | agent_1: 0.48 | agent_2: 0.78:   0%|          | 0/1500 [01:59<?, ?it/s]
# Iter [58/1500] | Rewards: agent_0: 1.32 | agent_1: -0.08 | agent_2: 0.32:   0%|          | 0/1500 [02:01<?, ?it/s]
# Iter [58/1500] | Rewards: agent_0: 1.32 | agent_1: -0.08 | agent_2: 0.32:   0%|          | 0/1500 [02:01<?, ?it/s]
# Iter [59/1500] | Rewards: agent_0: -0.03 | agent_1: -0.38 | agent_2: 0.42:   0%|          | 0/1500 [02:03<?, ?it/s]
# Iter [59/1500] | Rewards: agent_0: -0.03 | agent_1: -0.38 | agent_2: 0.42:   0%|          | 0/1500 [02:03<?, ?it/s]
# Iter [60/1500] | Rewards: agent_0: -0.04 | agent_1: -0.04 | agent_2: -0.14:   0%|          | 0/1500 [02:05<?, ?it/s]
# Iter [60/1500] | Rewards: agent_0: -0.04 | agent_1: -0.04 | agent_2: -0.14:   0%|          | 0/1500 [02:05<?, ?it/s]
# Iter [61/1500] | Rewards: agent_0: 0.58 | agent_1: 1.03 | agent_2: -0.12:   0%|          | 0/1500 [02:07<?, ?it/s]
# Iter [61/1500] | Rewards: agent_0: 0.58 | agent_1: 1.03 | agent_2: -0.12:   0%|          | 0/1500 [02:07<?, ?it/s]
# Iter [62/1500] | Rewards: agent_0: 0.03 | agent_1: 1.13 | agent_2: -0.42:   0%|          | 0/1500 [02:09<?, ?it/s]
# Iter [62/1500] | Rewards: agent_0: 0.03 | agent_1: 1.13 | agent_2: -0.42:   0%|          | 0/1500 [02:09<?, ?it/s]
# Iter [63/1500] | Rewards: agent_0: 1.57 | agent_1: 1.02 | agent_2: 1.17:   0%|          | 0/1500 [02:11<?, ?it/s]
# Iter [63/1500] | Rewards: agent_0: 1.57 | agent_1: 1.02 | agent_2: 1.17:   0%|          | 0/1500 [02:11<?, ?it/s]
# Iter [64/1500] | Rewards: agent_0: 0.10 | agent_1: -0.60 | agent_2: 0.70:   0%|          | 0/1500 [02:14<?, ?it/s]
# Iter [64/1500] | Rewards: agent_0: 0.10 | agent_1: -0.60 | agent_2: 0.70:   0%|          | 0/1500 [02:14<?, ?it/s]
# Iter [65/1500] | Rewards: agent_0: 1.31 | agent_1: 1.26 | agent_2: 1.06:   0%|          | 0/1500 [02:16<?, ?it/s]
# Iter [65/1500] | Rewards: agent_0: 1.31 | agent_1: 1.26 | agent_2: 1.06:   0%|          | 0/1500 [02:16<?, ?it/s]
# Iter [66/1500] | Rewards: agent_0: 0.45 | agent_1: 0.85 | agent_2: 0.85:   0%|          | 0/1500 [02:18<?, ?it/s]
# Iter [66/1500] | Rewards: agent_0: 0.45 | agent_1: 0.85 | agent_2: 0.85:   0%|          | 0/1500 [02:18<?, ?it/s]
# Iter [67/1500] | Rewards: agent_0: 0.53 | agent_1: 1.33 | agent_2: 0.58:   0%|          | 0/1500 [02:20<?, ?it/s]
# Iter [67/1500] | Rewards: agent_0: 0.53 | agent_1: 1.33 | agent_2: 0.58:   0%|          | 0/1500 [02:20<?, ?it/s]
# Iter [68/1500] | Rewards: agent_0: 1.99 | agent_1: 1.74 | agent_2: 1.89:   0%|          | 0/1500 [02:22<?, ?it/s]
# Iter [68/1500] | Rewards: agent_0: 1.99 | agent_1: 1.74 | agent_2: 1.89:   0%|          | 0/1500 [02:22<?, ?it/s]
# Iter [69/1500] | Rewards: agent_0: 0.63 | agent_1: 0.83 | agent_2: 0.43:   0%|          | 0/1500 [02:24<?, ?it/s]
# Iter [69/1500] | Rewards: agent_0: 0.63 | agent_1: 0.83 | agent_2: 0.43:   0%|          | 0/1500 [02:24<?, ?it/s]
# Iter [70/1500] | Rewards: agent_0: 1.96 | agent_1: 0.26 | agent_2: 0.41:   0%|          | 0/1500 [02:26<?, ?it/s]
# Iter [70/1500] | Rewards: agent_0: 1.96 | agent_1: 0.26 | agent_2: 0.41:   0%|          | 0/1500 [02:26<?, ?it/s]
# Iter [71/1500] | Rewards: agent_0: 1.05 | agent_1: 1.05 | agent_2: 1.45:   0%|          | 0/1500 [02:28<?, ?it/s]
# Iter [71/1500] | Rewards: agent_0: 1.05 | agent_1: 1.05 | agent_2: 1.45:   0%|          | 0/1500 [02:28<?, ?it/s]
# Iter [72/1500] | Rewards: agent_0: 2.03 | agent_1: 0.43 | agent_2: 0.48:   0%|          | 0/1500 [02:30<?, ?it/s]
# Iter [72/1500] | Rewards: agent_0: 2.03 | agent_1: 0.43 | agent_2: 0.48:   0%|          | 0/1500 [02:30<?, ?it/s]
# Iter [73/1500] | Rewards: agent_0: 1.22 | agent_1: 1.47 | agent_2: 1.37:   0%|          | 0/1500 [02:32<?, ?it/s]
# Iter [73/1500] | Rewards: agent_0: 1.22 | agent_1: 1.47 | agent_2: 1.37:   0%|          | 0/1500 [02:32<?, ?it/s]
# Iter [74/1500] | Rewards: agent_0: 0.32 | agent_1: 0.87 | agent_2: 1.07:   0%|          | 0/1500 [02:34<?, ?it/s]
# Iter [74/1500] | Rewards: agent_0: 0.32 | agent_1: 0.87 | agent_2: 1.07:   0%|          | 0/1500 [02:34<?, ?it/s]
# Iter [75/1500] | Rewards: agent_0: 1.40 | agent_1: 1.75 | agent_2: 1.35:   0%|          | 0/1500 [02:36<?, ?it/s]
# Iter [75/1500] | Rewards: agent_0: 1.40 | agent_1: 1.75 | agent_2: 1.35:   0%|          | 0/1500 [02:36<?, ?it/s]
# Iter [76/1500] | Rewards: agent_0: 1.49 | agent_1: 1.34 | agent_2: 1.44:   0%|          | 0/1500 [02:38<?, ?it/s]
# Iter [76/1500] | Rewards: agent_0: 1.49 | agent_1: 1.34 | agent_2: 1.44:   0%|          | 0/1500 [02:38<?, ?it/s]
# Iter [77/1500] | Rewards: agent_0: 1.49 | agent_1: 1.39 | agent_2: 1.49:   0%|          | 0/1500 [02:40<?, ?it/s]
# Iter [77/1500] | Rewards: agent_0: 1.49 | agent_1: 1.39 | agent_2: 1.49:   0%|          | 0/1500 [02:40<?, ?it/s]
# Iter [78/1500] | Rewards: agent_0: 1.92 | agent_1: 1.67 | agent_2: 1.67:   0%|          | 0/1500 [02:43<?, ?it/s]
# Iter [78/1500] | Rewards: agent_0: 1.92 | agent_1: 1.67 | agent_2: 1.67:   0%|          | 0/1500 [02:43<?, ?it/s]
# Iter [79/1500] | Rewards: agent_0: 1.35 | agent_1: -0.10 | agent_2: 0.00:   0%|          | 0/1500 [02:45<?, ?it/s]
# Iter [79/1500] | Rewards: agent_0: 1.35 | agent_1: -0.10 | agent_2: 0.00:   0%|          | 0/1500 [02:45<?, ?it/s]
# Iter [80/1500] | Rewards: agent_0: -0.00 | agent_1: 0.40 | agent_2: -0.10:   0%|          | 0/1500 [02:47<?, ?it/s]
# Iter [80/1500] | Rewards: agent_0: -0.00 | agent_1: 0.40 | agent_2: -0.10:   0%|          | 0/1500 [02:47<?, ?it/s]
# Iter [81/1500] | Rewards: agent_0: 0.88 | agent_1: 2.08 | agent_2: 0.88:   0%|          | 0/1500 [02:49<?, ?it/s]
# Iter [81/1500] | Rewards: agent_0: 0.88 | agent_1: 2.08 | agent_2: 0.88:   0%|          | 0/1500 [02:49<?, ?it/s]
# Iter [82/1500] | Rewards: agent_0: 0.44 | agent_1: 0.79 | agent_2: 1.59:   0%|          | 0/1500 [02:51<?, ?it/s]
# Iter [82/1500] | Rewards: agent_0: 0.44 | agent_1: 0.79 | agent_2: 1.59:   0%|          | 0/1500 [02:51<?, ?it/s]
# Iter [83/1500] | Rewards: agent_0: 0.99 | agent_1: 1.14 | agent_2: 1.44:   0%|          | 0/1500 [02:53<?, ?it/s]
# Iter [83/1500] | Rewards: agent_0: 0.99 | agent_1: 1.14 | agent_2: 1.44:   0%|          | 0/1500 [02:53<?, ?it/s]
# Iter [84/1500] | Rewards: agent_0: 1.71 | agent_1: 0.51 | agent_2: 0.56:   0%|          | 0/1500 [02:55<?, ?it/s]
# Iter [84/1500] | Rewards: agent_0: 1.71 | agent_1: 0.51 | agent_2: 0.56:   0%|          | 0/1500 [02:55<?, ?it/s]
# Iter [85/1500] | Rewards: agent_0: 2.18 | agent_1: 2.03 | agent_2: 2.13:   0%|          | 0/1500 [02:57<?, ?it/s]
# Iter [85/1500] | Rewards: agent_0: 2.18 | agent_1: 2.03 | agent_2: 2.13:   0%|          | 0/1500 [02:57<?, ?it/s]
# Iter [86/1500] | Rewards: agent_0: 1.35 | agent_1: 1.05 | agent_2: 1.60:   0%|          | 0/1500 [02:59<?, ?it/s]
# Iter [86/1500] | Rewards: agent_0: 1.35 | agent_1: 1.05 | agent_2: 1.60:   0%|          | 0/1500 [02:59<?, ?it/s]
# Iter [87/1500] | Rewards: agent_0: 1.73 | agent_1: 1.63 | agent_2: 2.33:   0%|          | 0/1500 [03:01<?, ?it/s]
# Iter [87/1500] | Rewards: agent_0: 1.73 | agent_1: 1.63 | agent_2: 2.33:   0%|          | 0/1500 [03:01<?, ?it/s]
# Iter [88/1500] | Rewards: agent_0: 1.97 | agent_1: 2.12 | agent_2: 1.87:   0%|          | 0/1500 [03:03<?, ?it/s]
# Iter [88/1500] | Rewards: agent_0: 1.97 | agent_1: 2.12 | agent_2: 1.87:   0%|          | 0/1500 [03:03<?, ?it/s]
# Iter [89/1500] | Rewards: agent_0: 2.01 | agent_1: 1.86 | agent_2: 2.06:   0%|          | 0/1500 [03:05<?, ?it/s]
# Iter [89/1500] | Rewards: agent_0: 2.01 | agent_1: 1.86 | agent_2: 2.06:   0%|          | 0/1500 [03:05<?, ?it/s]
# Iter [90/1500] | Rewards: agent_0: 1.85 | agent_1: 1.30 | agent_2: 0.90:   0%|          | 0/1500 [03:07<?, ?it/s]
# Iter [90/1500] | Rewards: agent_0: 1.85 | agent_1: 1.30 | agent_2: 0.90:   0%|          | 0/1500 [03:07<?, ?it/s]
# Iter [91/1500] | Rewards: agent_0: 1.50 | agent_1: 1.05 | agent_2: 1.70:   0%|          | 0/1500 [03:09<?, ?it/s]
# Iter [91/1500] | Rewards: agent_0: 1.50 | agent_1: 1.05 | agent_2: 1.70:   0%|          | 0/1500 [03:09<?, ?it/s]
# Iter [92/1500] | Rewards: agent_0: 1.88 | agent_1: 1.88 | agent_2: 1.83:   0%|          | 0/1500 [03:11<?, ?it/s]
# Iter [92/1500] | Rewards: agent_0: 1.88 | agent_1: 1.88 | agent_2: 1.83:   0%|          | 0/1500 [03:11<?, ?it/s]
# Iter [93/1500] | Rewards: agent_0: 1.55 | agent_1: 0.35 | agent_2: 0.50:   0%|          | 0/1500 [03:14<?, ?it/s]
# Iter [93/1500] | Rewards: agent_0: 1.55 | agent_1: 0.35 | agent_2: 0.50:   0%|          | 0/1500 [03:14<?, ?it/s]
# Iter [94/1500] | Rewards: agent_0: 0.91 | agent_1: 1.21 | agent_2: 1.71:   0%|          | 0/1500 [03:16<?, ?it/s]
# Iter [94/1500] | Rewards: agent_0: 0.91 | agent_1: 1.21 | agent_2: 1.71:   0%|          | 0/1500 [03:16<?, ?it/s]
# Iter [95/1500] | Rewards: agent_0: 1.58 | agent_1: 1.73 | agent_2: 1.73:   0%|          | 0/1500 [03:18<?, ?it/s]
# Iter [95/1500] | Rewards: agent_0: 1.58 | agent_1: 1.73 | agent_2: 1.73:   0%|          | 0/1500 [03:18<?, ?it/s]
# Iter [96/1500] | Rewards: agent_0: 1.95 | agent_1: 1.70 | agent_2: 1.90:   0%|          | 0/1500 [03:20<?, ?it/s]
# Iter [96/1500] | Rewards: agent_0: 1.95 | agent_1: 1.70 | agent_2: 1.90:   0%|          | 0/1500 [03:20<?, ?it/s]
# Iter [97/1500] | Rewards: agent_0: 1.63 | agent_1: 0.28 | agent_2: 1.08:   0%|          | 0/1500 [03:22<?, ?it/s]
# Iter [97/1500] | Rewards: agent_0: 1.63 | agent_1: 0.28 | agent_2: 1.08:   0%|          | 0/1500 [03:22<?, ?it/s]
# Iter [98/1500] | Rewards: agent_0: 1.57 | agent_1: 1.62 | agent_2: 1.97:   0%|          | 0/1500 [03:24<?, ?it/s]
# Iter [98/1500] | Rewards: agent_0: 1.57 | agent_1: 1.62 | agent_2: 1.97:   0%|          | 0/1500 [03:24<?, ?it/s]
# Iter [99/1500] | Rewards: agent_0: 2.02 | agent_1: 1.57 | agent_2: 1.47:   0%|          | 0/1500 [03:26<?, ?it/s]
# Iter [99/1500] | Rewards: agent_0: 2.02 | agent_1: 1.57 | agent_2: 1.47:   0%|          | 0/1500 [03:26<?, ?it/s]
# Iter [100/1500] | Rewards: agent_0: 1.97 | agent_1: 1.97 | agent_2: 2.22:   0%|          | 0/1500 [03:28<?, ?it/s]
# Iter [100/1500] | Rewards: agent_0: 1.97 | agent_1: 1.97 | agent_2: 2.22:   0%|          | 0/1500 [03:28<?, ?it/s]
# Iter [101/1500] | Rewards: agent_0: 1.37 | agent_1: 1.62 | agent_2: 1.37:   0%|          | 0/1500 [03:30<?, ?it/s]
# Iter [101/1500] | Rewards: agent_0: 1.37 | agent_1: 1.62 | agent_2: 1.37:   0%|          | 0/1500 [03:30<?, ?it/s]
# Iter [102/1500] | Rewards: agent_0: 1.74 | agent_1: 1.44 | agent_2: 1.49:   0%|          | 0/1500 [03:32<?, ?it/s]
# Iter [102/1500] | Rewards: agent_0: 1.74 | agent_1: 1.44 | agent_2: 1.49:   0%|          | 0/1500 [03:32<?, ?it/s]
# Iter [103/1500] | Rewards: agent_0: 2.05 | agent_1: 1.75 | agent_2: 1.60:   0%|          | 0/1500 [03:34<?, ?it/s]
# Iter [103/1500] | Rewards: agent_0: 2.05 | agent_1: 1.75 | agent_2: 1.60:   0%|          | 0/1500 [03:34<?, ?it/s]
# Iter [104/1500] | Rewards: agent_0: 0.72 | agent_1: 0.87 | agent_2: -0.03:   0%|          | 0/1500 [03:36<?, ?it/s]
# Iter [104/1500] | Rewards: agent_0: 0.72 | agent_1: 0.87 | agent_2: -0.03:   0%|          | 0/1500 [03:36<?, ?it/s]
# Iter [105/1500] | Rewards: agent_0: 2.07 | agent_1: 1.72 | agent_2: 1.67:   0%|          | 0/1500 [03:39<?, ?it/s]
# Iter [105/1500] | Rewards: agent_0: 2.07 | agent_1: 1.72 | agent_2: 1.67:   0%|          | 0/1500 [03:39<?, ?it/s]
# Iter [106/1500] | Rewards: agent_0: 2.19 | agent_1: 2.29 | agent_2: 1.99:   0%|          | 0/1500 [03:41<?, ?it/s]
# Iter [106/1500] | Rewards: agent_0: 2.19 | agent_1: 2.29 | agent_2: 1.99:   0%|          | 0/1500 [03:41<?, ?it/s]
# Iter [107/1500] | Rewards: agent_0: 2.02 | agent_1: 2.12 | agent_2: 2.12:   0%|          | 0/1500 [03:43<?, ?it/s]
# Iter [107/1500] | Rewards: agent_0: 2.02 | agent_1: 2.12 | agent_2: 2.12:   0%|          | 0/1500 [03:43<?, ?it/s]
# Iter [108/1500] | Rewards: agent_0: 2.03 | agent_1: 1.73 | agent_2: 2.08:   0%|          | 0/1500 [03:45<?, ?it/s]
# Iter [108/1500] | Rewards: agent_0: 2.03 | agent_1: 1.73 | agent_2: 2.08:   0%|          | 0/1500 [03:45<?, ?it/s]
# Iter [109/1500] | Rewards: agent_0: 1.88 | agent_1: 2.08 | agent_2: 2.23:   0%|          | 0/1500 [03:47<?, ?it/s]
# Iter [109/1500] | Rewards: agent_0: 1.88 | agent_1: 2.08 | agent_2: 2.23:   0%|          | 0/1500 [03:47<?, ?it/s]
# Iter [110/1500] | Rewards: agent_0: 1.31 | agent_1: 1.46 | agent_2: 1.81:   0%|          | 0/1500 [03:49<?, ?it/s]
# Iter [110/1500] | Rewards: agent_0: 1.31 | agent_1: 1.46 | agent_2: 1.81:   0%|          | 0/1500 [03:49<?, ?it/s]
# Iter [111/1500] | Rewards: agent_0: 1.44 | agent_1: 1.04 | agent_2: 1.39:   0%|          | 0/1500 [03:51<?, ?it/s]
# Iter [111/1500] | Rewards: agent_0: 1.44 | agent_1: 1.04 | agent_2: 1.39:   0%|          | 0/1500 [03:51<?, ?it/s]
# Iter [112/1500] | Rewards: agent_0: 1.09 | agent_1: 1.59 | agent_2: 0.89:   0%|          | 0/1500 [03:53<?, ?it/s]
# Iter [112/1500] | Rewards: agent_0: 1.09 | agent_1: 1.59 | agent_2: 0.89:   0%|          | 0/1500 [03:53<?, ?it/s]
# Iter [113/1500] | Rewards: agent_0: 1.52 | agent_1: 1.92 | agent_2: 1.47:   0%|          | 0/1500 [03:55<?, ?it/s]
# Iter [113/1500] | Rewards: agent_0: 1.52 | agent_1: 1.92 | agent_2: 1.47:   0%|          | 0/1500 [03:55<?, ?it/s]
# Iter [114/1500] | Rewards: agent_0: 0.99 | agent_1: 0.99 | agent_2: 1.24:   0%|          | 0/1500 [03:57<?, ?it/s]
# Iter [114/1500] | Rewards: agent_0: 0.99 | agent_1: 0.99 | agent_2: 1.24:   0%|          | 0/1500 [03:57<?, ?it/s]
# Iter [115/1500] | Rewards: agent_0: 1.96 | agent_1: 2.16 | agent_2: 1.71:   0%|          | 0/1500 [03:59<?, ?it/s]
# Iter [115/1500] | Rewards: agent_0: 1.96 | agent_1: 2.16 | agent_2: 1.71:   0%|          | 0/1500 [03:59<?, ?it/s]
# Iter [116/1500] | Rewards: agent_0: 2.23 | agent_1: 1.98 | agent_2: 2.18:   0%|          | 0/1500 [04:01<?, ?it/s]
# Iter [116/1500] | Rewards: agent_0: 2.23 | agent_1: 1.98 | agent_2: 2.18:   0%|          | 0/1500 [04:01<?, ?it/s]
# Iter [117/1500] | Rewards: agent_0: 1.93 | agent_1: 1.63 | agent_2: 1.53:   0%|          | 0/1500 [04:03<?, ?it/s]
# Iter [117/1500] | Rewards: agent_0: 1.93 | agent_1: 1.63 | agent_2: 1.53:   0%|          | 0/1500 [04:03<?, ?it/s]
# Iter [118/1500] | Rewards: agent_0: 1.91 | agent_1: 1.81 | agent_2: 2.26:   0%|          | 0/1500 [04:06<?, ?it/s]
# Iter [118/1500] | Rewards: agent_0: 1.91 | agent_1: 1.81 | agent_2: 2.26:   0%|          | 0/1500 [04:06<?, ?it/s]
# Iter [119/1500] | Rewards: agent_0: 1.64 | agent_1: 1.74 | agent_2: 1.59:   0%|          | 0/1500 [04:08<?, ?it/s]
# Iter [119/1500] | Rewards: agent_0: 1.64 | agent_1: 1.74 | agent_2: 1.59:   0%|          | 0/1500 [04:08<?, ?it/s]
# Iter [120/1500] | Rewards: agent_0: 1.22 | agent_1: 1.47 | agent_2: 1.97:   0%|          | 0/1500 [04:10<?, ?it/s]
# Iter [120/1500] | Rewards: agent_0: 1.22 | agent_1: 1.47 | agent_2: 1.97:   0%|          | 0/1500 [04:10<?, ?it/s]
# Iter [121/1500] | Rewards: agent_0: 2.11 | agent_1: 2.06 | agent_2: 2.06:   0%|          | 0/1500 [04:12<?, ?it/s]
# Iter [121/1500] | Rewards: agent_0: 2.11 | agent_1: 2.06 | agent_2: 2.06:   0%|          | 0/1500 [04:12<?, ?it/s]
# Iter [122/1500] | Rewards: agent_0: 1.54 | agent_1: 1.24 | agent_2: 1.24:   0%|          | 0/1500 [04:14<?, ?it/s]
# Iter [122/1500] | Rewards: agent_0: 1.54 | agent_1: 1.24 | agent_2: 1.24:   0%|          | 0/1500 [04:14<?, ?it/s]
# Iter [123/1500] | Rewards: agent_0: 1.04 | agent_1: 1.34 | agent_2: 1.34:   0%|          | 0/1500 [04:16<?, ?it/s]
# Iter [123/1500] | Rewards: agent_0: 1.04 | agent_1: 1.34 | agent_2: 1.34:   0%|          | 0/1500 [04:16<?, ?it/s]
# Iter [124/1500] | Rewards: agent_0: 2.25 | agent_1: 2.15 | agent_2: 2.35:   0%|          | 0/1500 [04:18<?, ?it/s]
# Iter [124/1500] | Rewards: agent_0: 2.25 | agent_1: 2.15 | agent_2: 2.35:   0%|          | 0/1500 [04:18<?, ?it/s]
# Iter [125/1500] | Rewards: agent_0: 1.98 | agent_1: 1.98 | agent_2: 1.98:   0%|          | 0/1500 [04:21<?, ?it/s]
# Iter [125/1500] | Rewards: agent_0: 1.98 | agent_1: 1.98 | agent_2: 1.98:   0%|          | 0/1500 [04:21<?, ?it/s]
# Iter [126/1500] | Rewards: agent_0: 2.38 | agent_1: 2.38 | agent_2: 2.48:   0%|          | 0/1500 [04:23<?, ?it/s]
# Iter [126/1500] | Rewards: agent_0: 2.38 | agent_1: 2.38 | agent_2: 2.48:   0%|          | 0/1500 [04:23<?, ?it/s]
# Iter [127/1500] | Rewards: agent_0: 2.13 | agent_1: 1.33 | agent_2: 1.58:   0%|          | 0/1500 [04:25<?, ?it/s]
# Iter [127/1500] | Rewards: agent_0: 2.13 | agent_1: 1.33 | agent_2: 1.58:   0%|          | 0/1500 [04:25<?, ?it/s]
# Iter [128/1500] | Rewards: agent_0: 1.66 | agent_1: 1.51 | agent_2: 2.46:   0%|          | 0/1500 [04:27<?, ?it/s]
# Iter [128/1500] | Rewards: agent_0: 1.66 | agent_1: 1.51 | agent_2: 2.46:   0%|          | 0/1500 [04:27<?, ?it/s]
# Iter [129/1500] | Rewards: agent_0: 1.68 | agent_1: 2.03 | agent_2: 2.18:   0%|          | 0/1500 [04:29<?, ?it/s]
# Iter [129/1500] | Rewards: agent_0: 1.68 | agent_1: 2.03 | agent_2: 2.18:   0%|          | 0/1500 [04:29<?, ?it/s]
# Iter [130/1500] | Rewards: agent_0: 1.59 | agent_1: 2.24 | agent_2: 1.39:   0%|          | 0/1500 [04:32<?, ?it/s]
# Iter [130/1500] | Rewards: agent_0: 1.59 | agent_1: 2.24 | agent_2: 1.39:   0%|          | 0/1500 [04:32<?, ?it/s]
# Iter [131/1500] | Rewards: agent_0: 1.71 | agent_1: 1.76 | agent_2: 1.41:   0%|          | 0/1500 [04:34<?, ?it/s]
# Iter [131/1500] | Rewards: agent_0: 1.71 | agent_1: 1.76 | agent_2: 1.41:   0%|          | 0/1500 [04:34<?, ?it/s]
# Iter [132/1500] | Rewards: agent_0: 2.14 | agent_1: 2.14 | agent_2: 2.09:   0%|          | 0/1500 [04:36<?, ?it/s]
# Iter [132/1500] | Rewards: agent_0: 2.14 | agent_1: 2.14 | agent_2: 2.09:   0%|          | 0/1500 [04:36<?, ?it/s]
# Iter [133/1500] | Rewards: agent_0: 2.17 | agent_1: 2.27 | agent_2: 2.02:   0%|          | 0/1500 [04:38<?, ?it/s]
# Iter [133/1500] | Rewards: agent_0: 2.17 | agent_1: 2.27 | agent_2: 2.02:   0%|          | 0/1500 [04:38<?, ?it/s]
# Iter [134/1500] | Rewards: agent_0: 2.49 | agent_1: 2.26 | agent_2: 2.07:   0%|          | 0/1500 [04:40<?, ?it/s]
# Iter [134/1500] | Rewards: agent_0: 2.49 | agent_1: 2.26 | agent_2: 2.07:   0%|          | 0/1500 [04:40<?, ?it/s]
# Iter [135/1500] | Rewards: agent_0: 1.88 | agent_1: 2.13 | agent_2: 2.08:   0%|          | 0/1500 [04:42<?, ?it/s]
# Iter [135/1500] | Rewards: agent_0: 1.88 | agent_1: 2.13 | agent_2: 2.08:   0%|          | 0/1500 [04:42<?, ?it/s]
# Iter [136/1500] | Rewards: agent_0: 2.00 | agent_1: 2.30 | agent_2: 1.90:   0%|          | 0/1500 [04:44<?, ?it/s]
# Iter [136/1500] | Rewards: agent_0: 2.00 | agent_1: 2.30 | agent_2: 1.90:   0%|          | 0/1500 [04:44<?, ?it/s]
# Iter [137/1500] | Rewards: agent_0: 2.21 | agent_1: 2.01 | agent_2: 2.06:   0%|          | 0/1500 [04:47<?, ?it/s]
# Iter [137/1500] | Rewards: agent_0: 2.21 | agent_1: 2.01 | agent_2: 2.06:   0%|          | 0/1500 [04:47<?, ?it/s]
# Iter [138/1500] | Rewards: agent_0: 2.32 | agent_1: 2.02 | agent_2: 2.02:   0%|          | 0/1500 [04:49<?, ?it/s]
# Iter [138/1500] | Rewards: agent_0: 2.32 | agent_1: 2.02 | agent_2: 2.02:   0%|          | 0/1500 [04:49<?, ?it/s]
# Iter [139/1500] | Rewards: agent_0: 1.21 | agent_1: 1.41 | agent_2: 1.76:   0%|          | 0/1500 [04:51<?, ?it/s]
# Iter [139/1500] | Rewards: agent_0: 1.21 | agent_1: 1.41 | agent_2: 1.76:   0%|          | 0/1500 [04:51<?, ?it/s]
# Iter [140/1500] | Rewards: agent_0: 2.58 | agent_1: 2.28 | agent_2: 2.48:   0%|          | 0/1500 [04:53<?, ?it/s]
# Iter [140/1500] | Rewards: agent_0: 2.58 | agent_1: 2.28 | agent_2: 2.48:   0%|          | 0/1500 [04:53<?, ?it/s]
# Iter [141/1500] | Rewards: agent_0: 2.02 | agent_1: 2.27 | agent_2: 2.52:   0%|          | 0/1500 [04:55<?, ?it/s]
# Iter [141/1500] | Rewards: agent_0: 2.02 | agent_1: 2.27 | agent_2: 2.52:   0%|          | 0/1500 [04:55<?, ?it/s]
# Iter [142/1500] | Rewards: agent_0: 2.31 | agent_1: 2.56 | agent_2: 2.06:   0%|          | 0/1500 [04:58<?, ?it/s]
# Iter [142/1500] | Rewards: agent_0: 2.31 | agent_1: 2.56 | agent_2: 2.06:   0%|          | 0/1500 [04:58<?, ?it/s]
# Iter [143/1500] | Rewards: agent_0: 2.25 | agent_1: 2.25 | agent_2: 2.20:   0%|          | 0/1500 [05:00<?, ?it/s]
# Iter [143/1500] | Rewards: agent_0: 2.25 | agent_1: 2.25 | agent_2: 2.20:   0%|          | 0/1500 [05:00<?, ?it/s]
# Iter [144/1500] | Rewards: agent_0: 2.15 | agent_1: 2.00 | agent_2: 2.10:   0%|          | 0/1500 [05:02<?, ?it/s]
# Iter [144/1500] | Rewards: agent_0: 2.15 | agent_1: 2.00 | agent_2: 2.10:   0%|          | 0/1500 [05:02<?, ?it/s]
# Iter [145/1500] | Rewards: agent_0: 2.03 | agent_1: 2.13 | agent_2: 2.33:   0%|          | 0/1500 [05:04<?, ?it/s]
# Iter [145/1500] | Rewards: agent_0: 2.03 | agent_1: 2.13 | agent_2: 2.33:   0%|          | 0/1500 [05:04<?, ?it/s]
# Iter [146/1500] | Rewards: agent_0: 2.22 | agent_1: 2.52 | agent_2: 1.97:   0%|          | 0/1500 [05:06<?, ?it/s]
# Iter [146/1500] | Rewards: agent_0: 2.22 | agent_1: 2.52 | agent_2: 1.97:   0%|          | 0/1500 [05:06<?, ?it/s]
# Iter [147/1500] | Rewards: agent_0: 2.15 | agent_1: 2.43 | agent_2: 2.15:   0%|          | 0/1500 [05:09<?, ?it/s]
# Iter [147/1500] | Rewards: agent_0: 2.15 | agent_1: 2.43 | agent_2: 2.15:   0%|          | 0/1500 [05:09<?, ?it/s]
# Iter [148/1500] | Rewards: agent_0: 1.92 | agent_1: 2.07 | agent_2: 2.12:   0%|          | 0/1500 [05:11<?, ?it/s]
# Iter [148/1500] | Rewards: agent_0: 1.92 | agent_1: 2.07 | agent_2: 2.12:   0%|          | 0/1500 [05:11<?, ?it/s]
# Iter [149/1500] | Rewards: agent_0: 2.53 | agent_1: 2.29 | agent_2: 2.53:   0%|          | 0/1500 [05:13<?, ?it/s]
# Iter [149/1500] | Rewards: agent_0: 2.53 | agent_1: 2.29 | agent_2: 2.53:   0%|          | 0/1500 [05:13<?, ?it/s]
# Iter [150/1500] | Rewards: agent_0: 1.56 | agent_1: 1.94 | agent_2: 1.71:   0%|          | 0/1500 [05:15<?, ?it/s]
# Iter [150/1500] | Rewards: agent_0: 1.56 | agent_1: 1.94 | agent_2: 1.71:   0%|          | 0/1500 [05:15<?, ?it/s]
# Iter [151/1500] | Rewards: agent_0: 2.36 | agent_1: 2.51 | agent_2: 2.27:   0%|          | 0/1500 [05:17<?, ?it/s]
# Iter [151/1500] | Rewards: agent_0: 2.36 | agent_1: 2.51 | agent_2: 2.27:   0%|          | 0/1500 [05:17<?, ?it/s]
# Iter [152/1500] | Rewards: agent_0: 2.15 | agent_1: 2.35 | agent_2: 2.25:   0%|          | 0/1500 [05:20<?, ?it/s]
# Iter [152/1500] | Rewards: agent_0: 2.15 | agent_1: 2.35 | agent_2: 2.25:   0%|          | 0/1500 [05:20<?, ?it/s]
# Iter [153/1500] | Rewards: agent_0: 2.32 | agent_1: 2.37 | agent_2: 2.47:   0%|          | 0/1500 [05:22<?, ?it/s]
# Iter [153/1500] | Rewards: agent_0: 2.32 | agent_1: 2.37 | agent_2: 2.47:   0%|          | 0/1500 [05:22<?, ?it/s]
# Iter [154/1500] | Rewards: agent_0: 2.18 | agent_1: 2.28 | agent_2: 2.18:   0%|          | 0/1500 [05:24<?, ?it/s]
# Iter [154/1500] | Rewards: agent_0: 2.18 | agent_1: 2.28 | agent_2: 2.18:   0%|          | 0/1500 [05:24<?, ?it/s]
# Iter [155/1500] | Rewards: agent_0: 1.83 | agent_1: 2.28 | agent_2: 2.03:   0%|          | 0/1500 [05:26<?, ?it/s]
# Iter [155/1500] | Rewards: agent_0: 1.83 | agent_1: 2.28 | agent_2: 2.03:   0%|          | 0/1500 [05:26<?, ?it/s]
# Iter [156/1500] | Rewards: agent_0: 2.67 | agent_1: 2.57 | agent_2: 2.52:   0%|          | 0/1500 [05:28<?, ?it/s]
# Iter [156/1500] | Rewards: agent_0: 2.67 | agent_1: 2.57 | agent_2: 2.52:   0%|          | 0/1500 [05:28<?, ?it/s]
# Iter [157/1500] | Rewards: agent_0: 2.48 | agent_1: 2.48 | agent_2: 2.38:   0%|          | 0/1500 [05:31<?, ?it/s]
# Iter [157/1500] | Rewards: agent_0: 2.48 | agent_1: 2.48 | agent_2: 2.38:   0%|          | 0/1500 [05:31<?, ?it/s]
# Iter [158/1500] | Rewards: agent_0: 3.05 | agent_1: 3.00 | agent_2: 3.05:   0%|          | 0/1500 [05:33<?, ?it/s]
# Iter [158/1500] | Rewards: agent_0: 3.05 | agent_1: 3.00 | agent_2: 3.05:   0%|          | 0/1500 [05:33<?, ?it/s]
# Iter [159/1500] | Rewards: agent_0: 2.60 | agent_1: 2.40 | agent_2: 2.40:   0%|          | 0/1500 [05:35<?, ?it/s]
# Iter [159/1500] | Rewards: agent_0: 2.60 | agent_1: 2.40 | agent_2: 2.40:   0%|          | 0/1500 [05:35<?, ?it/s]
# Iter [160/1500] | Rewards: agent_0: 1.88 | agent_1: 1.93 | agent_2: 1.78:   0%|          | 0/1500 [05:37<?, ?it/s]
# Iter [160/1500] | Rewards: agent_0: 1.88 | agent_1: 1.93 | agent_2: 1.78:   0%|          | 0/1500 [05:37<?, ?it/s]
# Iter [161/1500] | Rewards: agent_0: 2.33 | agent_1: 2.28 | agent_2: 2.28:   0%|          | 0/1500 [05:39<?, ?it/s]
# Iter [161/1500] | Rewards: agent_0: 2.33 | agent_1: 2.28 | agent_2: 2.28:   0%|          | 0/1500 [05:39<?, ?it/s]
# Iter [162/1500] | Rewards: agent_0: 2.31 | agent_1: 2.11 | agent_2: 2.31:   0%|          | 0/1500 [05:42<?, ?it/s]
# Iter [162/1500] | Rewards: agent_0: 2.31 | agent_1: 2.11 | agent_2: 2.31:   0%|          | 0/1500 [05:42<?, ?it/s]
# Iter [163/1500] | Rewards: agent_0: 2.21 | agent_1: 2.51 | agent_2: 2.36:   0%|          | 0/1500 [05:44<?, ?it/s]
# Iter [163/1500] | Rewards: agent_0: 2.21 | agent_1: 2.51 | agent_2: 2.36:   0%|          | 0/1500 [05:44<?, ?it/s]
# Iter [164/1500] | Rewards: agent_0: 2.25 | agent_1: 2.43 | agent_2: 2.29:   0%|          | 0/1500 [05:46<?, ?it/s]
# Iter [164/1500] | Rewards: agent_0: 2.25 | agent_1: 2.43 | agent_2: 2.29:   0%|          | 0/1500 [05:46<?, ?it/s]
# Iter [165/1500] | Rewards: agent_0: 2.57 | agent_1: 2.52 | agent_2: 2.62:   0%|          | 0/1500 [05:48<?, ?it/s]
# Iter [165/1500] | Rewards: agent_0: 2.57 | agent_1: 2.52 | agent_2: 2.62:   0%|          | 0/1500 [05:48<?, ?it/s]
# Iter [166/1500] | Rewards: agent_0: 2.22 | agent_1: 2.22 | agent_2: 2.27:   0%|          | 0/1500 [05:51<?, ?it/s]
# Iter [166/1500] | Rewards: agent_0: 2.22 | agent_1: 2.22 | agent_2: 2.27:   0%|          | 0/1500 [05:51<?, ?it/s]
# Iter [167/1500] | Rewards: agent_0: 2.15 | agent_1: 2.20 | agent_2: 2.44:   0%|          | 0/1500 [05:53<?, ?it/s]
# Iter [167/1500] | Rewards: agent_0: 2.15 | agent_1: 2.20 | agent_2: 2.44:   0%|          | 0/1500 [05:53<?, ?it/s]
# Iter [168/1500] | Rewards: agent_0: 2.66 | agent_1: 2.61 | agent_2: 2.86:   0%|          | 0/1500 [05:55<?, ?it/s]
# Iter [168/1500] | Rewards: agent_0: 2.66 | agent_1: 2.61 | agent_2: 2.86:   0%|          | 0/1500 [05:55<?, ?it/s]
# Iter [169/1500] | Rewards: agent_0: 2.13 | agent_1: 2.41 | agent_2: 1.98:   0%|          | 0/1500 [05:57<?, ?it/s]
# Iter [169/1500] | Rewards: agent_0: 2.13 | agent_1: 2.41 | agent_2: 1.98:   0%|          | 0/1500 [05:57<?, ?it/s]
# Iter [170/1500] | Rewards: agent_0: 2.48 | agent_1: 2.48 | agent_2: 2.58:   0%|          | 0/1500 [06:00<?, ?it/s]
# Iter [170/1500] | Rewards: agent_0: 2.48 | agent_1: 2.48 | agent_2: 2.58:   0%|          | 0/1500 [06:00<?, ?it/s]
# Iter [171/1500] | Rewards: agent_0: 2.39 | agent_1: 2.58 | agent_2: 2.39:   0%|          | 0/1500 [06:02<?, ?it/s]
# Iter [171/1500] | Rewards: agent_0: 2.39 | agent_1: 2.58 | agent_2: 2.39:   0%|          | 0/1500 [06:02<?, ?it/s]
# Iter [172/1500] | Rewards: agent_0: 2.38 | agent_1: 2.76 | agent_2: 2.43:   0%|          | 0/1500 [06:04<?, ?it/s]
# Iter [172/1500] | Rewards: agent_0: 2.38 | agent_1: 2.76 | agent_2: 2.43:   0%|          | 0/1500 [06:04<?, ?it/s]
# Iter [173/1500] | Rewards: agent_0: 2.84 | agent_1: 2.84 | agent_2: 2.74:   0%|          | 0/1500 [06:06<?, ?it/s]
# Iter [173/1500] | Rewards: agent_0: 2.84 | agent_1: 2.84 | agent_2: 2.74:   0%|          | 0/1500 [06:06<?, ?it/s]
# Iter [174/1500] | Rewards: agent_0: 2.58 | agent_1: 2.63 | agent_2: 2.68:   0%|          | 0/1500 [06:09<?, ?it/s]
# Iter [174/1500] | Rewards: agent_0: 2.58 | agent_1: 2.63 | agent_2: 2.68:   0%|          | 0/1500 [06:09<?, ?it/s]
# Iter [175/1500] | Rewards: agent_0: 2.48 | agent_1: 2.48 | agent_2: 2.43:   0%|          | 0/1500 [06:11<?, ?it/s]
# Iter [175/1500] | Rewards: agent_0: 2.48 | agent_1: 2.48 | agent_2: 2.43:   0%|          | 0/1500 [06:11<?, ?it/s]
# Iter [176/1500] | Rewards: agent_0: 2.60 | agent_1: 2.70 | agent_2: 2.60:   0%|          | 0/1500 [06:13<?, ?it/s]
# Iter [176/1500] | Rewards: agent_0: 2.60 | agent_1: 2.70 | agent_2: 2.60:   0%|          | 0/1500 [06:13<?, ?it/s]
# Iter [177/1500] | Rewards: agent_0: 2.40 | agent_1: 2.55 | agent_2: 2.45:   0%|          | 0/1500 [06:15<?, ?it/s]
# Iter [177/1500] | Rewards: agent_0: 2.40 | agent_1: 2.55 | agent_2: 2.45:   0%|          | 0/1500 [06:15<?, ?it/s]
# Iter [178/1500] | Rewards: agent_0: 2.49 | agent_1: 2.59 | agent_2: 2.54:   0%|          | 0/1500 [06:18<?, ?it/s]
# Iter [178/1500] | Rewards: agent_0: 2.49 | agent_1: 2.59 | agent_2: 2.54:   0%|          | 0/1500 [06:18<?, ?it/s]
# Iter [179/1500] | Rewards: agent_0: 2.61 | agent_1: 2.46 | agent_2: 2.56:   0%|          | 0/1500 [06:20<?, ?it/s]
# Iter [179/1500] | Rewards: agent_0: 2.61 | agent_1: 2.46 | agent_2: 2.56:   0%|          | 0/1500 [06:20<?, ?it/s]
# Iter [180/1500] | Rewards: agent_0: 1.82 | agent_1: 1.87 | agent_2: 2.06:   0%|          | 0/1500 [06:22<?, ?it/s]
# Iter [180/1500] | Rewards: agent_0: 1.82 | agent_1: 1.87 | agent_2: 2.06:   0%|          | 0/1500 [06:22<?, ?it/s]
# Iter [181/1500] | Rewards: agent_0: 2.26 | agent_1: 2.21 | agent_2: 2.16:   0%|          | 0/1500 [06:24<?, ?it/s]
# Iter [181/1500] | Rewards: agent_0: 2.26 | agent_1: 2.21 | agent_2: 2.16:   0%|          | 0/1500 [06:24<?, ?it/s]
# Iter [182/1500] | Rewards: agent_0: 2.70 | agent_1: 2.60 | agent_2: 2.70:   0%|          | 0/1500 [06:27<?, ?it/s]
# Iter [182/1500] | Rewards: agent_0: 2.70 | agent_1: 2.60 | agent_2: 2.70:   0%|          | 0/1500 [06:27<?, ?it/s]
# Iter [183/1500] | Rewards: agent_0: 2.21 | agent_1: 2.16 | agent_2: 2.16:   0%|          | 0/1500 [06:29<?, ?it/s]
# Iter [183/1500] | Rewards: agent_0: 2.21 | agent_1: 2.16 | agent_2: 2.16:   0%|          | 0/1500 [06:29<?, ?it/s]
# Iter [184/1500] | Rewards: agent_0: 2.19 | agent_1: 2.24 | agent_2: 2.14:   0%|          | 0/1500 [06:31<?, ?it/s]
# Iter [184/1500] | Rewards: agent_0: 2.19 | agent_1: 2.24 | agent_2: 2.14:   0%|          | 0/1500 [06:31<?, ?it/s]
# Iter [185/1500] | Rewards: agent_0: 2.62 | agent_1: 2.62 | agent_2: 2.67:   0%|          | 0/1500 [06:33<?, ?it/s]
# Iter [185/1500] | Rewards: agent_0: 2.62 | agent_1: 2.62 | agent_2: 2.67:   0%|          | 0/1500 [06:33<?, ?it/s]
# Iter [186/1500] | Rewards: agent_0: 2.85 | agent_1: 2.75 | agent_2: 2.75:   0%|          | 0/1500 [06:35<?, ?it/s]
# Iter [186/1500] | Rewards: agent_0: 2.85 | agent_1: 2.75 | agent_2: 2.75:   0%|          | 0/1500 [06:35<?, ?it/s]
# Iter [187/1500] | Rewards: agent_0: 2.30 | agent_1: 2.35 | agent_2: 2.30:   0%|          | 0/1500 [06:38<?, ?it/s]
# Iter [187/1500] | Rewards: agent_0: 2.30 | agent_1: 2.35 | agent_2: 2.30:   0%|          | 0/1500 [06:38<?, ?it/s]
# Iter [188/1500] | Rewards: agent_0: 2.48 | agent_1: 2.40 | agent_2: 2.23:   0%|          | 0/1500 [06:40<?, ?it/s]
# Iter [188/1500] | Rewards: agent_0: 2.48 | agent_1: 2.40 | agent_2: 2.23:   0%|          | 0/1500 [06:40<?, ?it/s]
# Iter [189/1500] | Rewards: agent_0: 2.57 | agent_1: 2.67 | agent_2: 2.57:   0%|          | 0/1500 [06:42<?, ?it/s]
# Iter [189/1500] | Rewards: agent_0: 2.57 | agent_1: 2.67 | agent_2: 2.57:   0%|          | 0/1500 [06:42<?, ?it/s]
# Iter [190/1500] | Rewards: agent_0: 2.49 | agent_1: 2.49 | agent_2: 2.69:   0%|          | 0/1500 [06:44<?, ?it/s]
# Iter [190/1500] | Rewards: agent_0: 2.49 | agent_1: 2.49 | agent_2: 2.69:   0%|          | 0/1500 [06:44<?, ?it/s]
# Iter [191/1500] | Rewards: agent_0: 2.49 | agent_1: 2.64 | agent_2: 2.39:   0%|          | 0/1500 [06:47<?, ?it/s]
# Iter [191/1500] | Rewards: agent_0: 2.49 | agent_1: 2.64 | agent_2: 2.39:   0%|          | 0/1500 [06:47<?, ?it/s]
# Iter [192/1500] | Rewards: agent_0: 2.44 | agent_1: 2.34 | agent_2: 2.29:   0%|          | 0/1500 [06:49<?, ?it/s]
# Iter [192/1500] | Rewards: agent_0: 2.44 | agent_1: 2.34 | agent_2: 2.29:   0%|          | 0/1500 [06:49<?, ?it/s]
# Iter [193/1500] | Rewards: agent_0: 2.41 | agent_1: 2.58 | agent_2: 2.58:   0%|          | 0/1500 [06:51<?, ?it/s]
# Iter [193/1500] | Rewards: agent_0: 2.41 | agent_1: 2.58 | agent_2: 2.58:   0%|          | 0/1500 [06:51<?, ?it/s]
# Iter [194/1500] | Rewards: agent_0: 2.77 | agent_1: 2.53 | agent_2: 2.63:   0%|          | 0/1500 [06:53<?, ?it/s]
# Iter [194/1500] | Rewards: agent_0: 2.77 | agent_1: 2.53 | agent_2: 2.63:   0%|          | 0/1500 [06:53<?, ?it/s]
# Iter [195/1500] | Rewards: agent_0: 2.14 | agent_1: 2.19 | agent_2: 2.24:   0%|          | 0/1500 [06:56<?, ?it/s]
# Iter [195/1500] | Rewards: agent_0: 2.14 | agent_1: 2.19 | agent_2: 2.24:   0%|          | 0/1500 [06:56<?, ?it/s]
# Iter [196/1500] | Rewards: agent_0: 2.74 | agent_1: 2.64 | agent_2: 2.50:   0%|          | 0/1500 [06:58<?, ?it/s]
# Iter [196/1500] | Rewards: agent_0: 2.74 | agent_1: 2.64 | agent_2: 2.50:   0%|          | 0/1500 [06:58<?, ?it/s]
# Iter [197/1500] | Rewards: agent_0: 3.06 | agent_1: 2.71 | agent_2: 2.76:   0%|          | 0/1500 [07:00<?, ?it/s]
# Iter [197/1500] | Rewards: agent_0: 3.06 | agent_1: 2.71 | agent_2: 2.76:   0%|          | 0/1500 [07:00<?, ?it/s]
# Iter [198/1500] | Rewards: agent_0: 2.48 | agent_1: 2.48 | agent_2: 2.48:   0%|          | 0/1500 [07:02<?, ?it/s]
# Iter [198/1500] | Rewards: agent_0: 2.48 | agent_1: 2.48 | agent_2: 2.48:   0%|          | 0/1500 [07:02<?, ?it/s]
# Iter [199/1500] | Rewards: agent_0: 2.67 | agent_1: 2.95 | agent_2: 2.53:   0%|          | 0/1500 [07:04<?, ?it/s]
# Iter [199/1500] | Rewards: agent_0: 2.67 | agent_1: 2.95 | agent_2: 2.53:   0%|          | 0/1500 [07:04<?, ?it/s]
# Iter [200/1500] | Rewards: agent_0: 2.67 | agent_1: 2.67 | agent_2: 2.39:   0%|          | 0/1500 [07:07<?, ?it/s]
# Iter [200/1500] | Rewards: agent_0: 2.67 | agent_1: 2.67 | agent_2: 2.39:   0%|          | 0/1500 [07:07<?, ?it/s]
# Iter [201/1500] | Rewards: agent_0: 2.64 | agent_1: 2.55 | agent_2: 2.55:   0%|          | 0/1500 [07:09<?, ?it/s]
# Iter [201/1500] | Rewards: agent_0: 2.64 | agent_1: 2.55 | agent_2: 2.55:   0%|          | 0/1500 [07:09<?, ?it/s]
# Iter [202/1500] | Rewards: agent_0: 2.78 | agent_1: 2.51 | agent_2: 2.60:   0%|          | 0/1500 [07:11<?, ?it/s]
# Iter [202/1500] | Rewards: agent_0: 2.78 | agent_1: 2.51 | agent_2: 2.60:   0%|          | 0/1500 [07:11<?, ?it/s]
# Iter [203/1500] | Rewards: agent_0: 2.66 | agent_1: 2.48 | agent_2: 2.52:   0%|          | 0/1500 [07:14<?, ?it/s]
# Iter [203/1500] | Rewards: agent_0: 2.66 | agent_1: 2.48 | agent_2: 2.52:   0%|          | 0/1500 [07:14<?, ?it/s]
# Iter [204/1500] | Rewards: agent_0: 2.37 | agent_1: 2.23 | agent_2: 2.37:   0%|          | 0/1500 [07:16<?, ?it/s]
# Iter [204/1500] | Rewards: agent_0: 2.37 | agent_1: 2.23 | agent_2: 2.37:   0%|          | 0/1500 [07:16<?, ?it/s]
# Iter [205/1500] | Rewards: agent_0: 2.51 | agent_1: 2.51 | agent_2: 2.51:   0%|          | 0/1500 [07:18<?, ?it/s]
# Iter [205/1500] | Rewards: agent_0: 2.51 | agent_1: 2.51 | agent_2: 2.51:   0%|          | 0/1500 [07:18<?, ?it/s]
# Iter [206/1500] | Rewards: agent_0: 2.55 | agent_1: 2.46 | agent_2: 2.32:   0%|          | 0/1500 [07:20<?, ?it/s]
# Iter [206/1500] | Rewards: agent_0: 2.55 | agent_1: 2.46 | agent_2: 2.32:   0%|          | 0/1500 [07:20<?, ?it/s]
# Iter [207/1500] | Rewards: agent_0: 2.82 | agent_1: 2.92 | agent_2: 3.01:   0%|          | 0/1500 [07:23<?, ?it/s]
# Iter [207/1500] | Rewards: agent_0: 2.82 | agent_1: 2.92 | agent_2: 3.01:   0%|          | 0/1500 [07:23<?, ?it/s]
# Iter [209/1500] | Rewards: agent_0: 2.41 | agent_1: 2.45 | agent_2: 2.31:   0%|          | 0/1500 [07:27<?, ?it/s]
# ...
# Iter [1432/1500] | Rewards: agent_0: 1.10 | agent_1: 1.10 | agent_2: 1.10:   0%|          | 0/1500 [52:47<?, ?it/s]
# Iter [1433/1500] | Rewards: agent_0: 1.77 | agent_1: 1.77 | agent_2: 1.77:   0%|          | 0/1500 [52:49<?, ?it/s]
# Iter [1433/1500] | Rewards: agent_0: 1.77 | agent_1: 1.77 | agent_2: 1.77:   0%|          | 0/1500 [52:49<?, ?it/s]
# Iter [1434/1500] | Rewards: agent_0: 1.68 | agent_1: 1.68 | agent_2: 1.68:   0%|          | 0/1500 [52:51<?, ?it/s]
# Iter [1434/1500] | Rewards: agent_0: 1.68 | agent_1: 1.68 | agent_2: 1.68:   0%|          | 0/1500 [52:51<?, ?it/s]
# Iter [1435/1500] | Rewards: agent_0: 1.20 | agent_1: 1.20 | agent_2: 1.25:   0%|          | 0/1500 [52:53<?, ?it/s]
# Iter [1435/1500] | Rewards: agent_0: 1.20 | agent_1: 1.20 | agent_2: 1.25:   0%|          | 0/1500 [52:53<?, ?it/s]
# Iter [1436/1500] | Rewards: agent_0: 1.58 | agent_1: 1.58 | agent_2: 1.58:   0%|          | 0/1500 [52:56<?, ?it/s]
# Iter [1436/1500] | Rewards: agent_0: 1.58 | agent_1: 1.58 | agent_2: 1.58:   0%|          | 0/1500 [52:56<?, ?it/s]
# Iter [1437/1500] | Rewards: agent_0: 1.30 | agent_1: 1.25 | agent_2: 1.25:   0%|          | 0/1500 [52:58<?, ?it/s]
# Iter [1437/1500] | Rewards: agent_0: 1.30 | agent_1: 1.25 | agent_2: 1.25:   0%|          | 0/1500 [52:58<?, ?it/s]
# Iter [1438/1500] | Rewards: agent_0: 1.33 | agent_1: 1.33 | agent_2: 1.33:   0%|          | 0/1500 [53:00<?, ?it/s]
# Iter [1438/1500] | Rewards: agent_0: 1.33 | agent_1: 1.33 | agent_2: 1.33:   0%|          | 0/1500 [53:00<?, ?it/s]
# Iter [1439/1500] | Rewards: agent_0: 1.48 | agent_1: 1.48 | agent_2: 1.48:   0%|          | 0/1500 [53:02<?, ?it/s]
# Iter [1439/1500] | Rewards: agent_0: 1.48 | agent_1: 1.48 | agent_2: 1.48:   0%|          | 0/1500 [53:02<?, ?it/s]
# Iter [1440/1500] | Rewards: agent_0: 1.41 | agent_1: 1.41 | agent_2: 1.41:   0%|          | 0/1500 [53:04<?, ?it/s]
# Iter [1440/1500] | Rewards: agent_0: 1.41 | agent_1: 1.41 | agent_2: 1.41:   0%|          | 0/1500 [53:04<?, ?it/s]
# Iter [1441/1500] | Rewards: agent_0: 1.13 | agent_1: 1.13 | agent_2: 1.13:   0%|          | 0/1500 [53:06<?, ?it/s]
# Iter [1441/1500] | Rewards: agent_0: 1.13 | agent_1: 1.13 | agent_2: 1.13:   0%|          | 0/1500 [53:06<?, ?it/s]
# Iter [1442/1500] | Rewards: agent_0: 1.15 | agent_1: 1.15 | agent_2: 1.15:   0%|          | 0/1500 [53:08<?, ?it/s]
# Iter [1442/1500] | Rewards: agent_0: 1.15 | agent_1: 1.15 | agent_2: 1.15:   0%|          | 0/1500 [53:08<?, ?it/s]
# Iter [1443/1500] | Rewards: agent_0: 1.27 | agent_1: 1.22 | agent_2: 1.22:   0%|          | 0/1500 [53:11<?, ?it/s]
# Iter [1443/1500] | Rewards: agent_0: 1.27 | agent_1: 1.22 | agent_2: 1.22:   0%|          | 0/1500 [53:11<?, ?it/s]
# Iter [1444/1500] | Rewards: agent_0: 0.78 | agent_1: 0.78 | agent_2: 0.83:   0%|          | 0/1500 [53:13<?, ?it/s]
# Iter [1444/1500] | Rewards: agent_0: 0.78 | agent_1: 0.78 | agent_2: 0.83:   0%|          | 0/1500 [53:13<?, ?it/s]
# Iter [1445/1500] | Rewards: agent_0: 1.61 | agent_1: 1.61 | agent_2: 1.61:   0%|          | 0/1500 [53:15<?, ?it/s]
# Iter [1445/1500] | Rewards: agent_0: 1.61 | agent_1: 1.61 | agent_2: 1.61:   0%|          | 0/1500 [53:15<?, ?it/s]
# Iter [1446/1500] | Rewards: agent_0: 1.63 | agent_1: 1.58 | agent_2: 1.58:   0%|          | 0/1500 [53:17<?, ?it/s]
# Iter [1446/1500] | Rewards: agent_0: 1.63 | agent_1: 1.58 | agent_2: 1.58:   0%|          | 0/1500 [53:17<?, ?it/s]
# Iter [1447/1500] | Rewards: agent_0: 1.52 | agent_1: 1.52 | agent_2: 1.52:   0%|          | 0/1500 [53:19<?, ?it/s]
# Iter [1447/1500] | Rewards: agent_0: 1.52 | agent_1: 1.52 | agent_2: 1.52:   0%|          | 0/1500 [53:19<?, ?it/s]
# Iter [1448/1500] | Rewards: agent_0: 2.01 | agent_1: 2.01 | agent_2: 2.01:   0%|          | 0/1500 [53:21<?, ?it/s]
# Iter [1448/1500] | Rewards: agent_0: 2.01 | agent_1: 2.01 | agent_2: 2.01:   0%|          | 0/1500 [53:21<?, ?it/s]
# Iter [1449/1500] | Rewards: agent_0: 1.19 | agent_1: 1.19 | agent_2: 1.19:   0%|          | 0/1500 [53:24<?, ?it/s]
# Iter [1449/1500] | Rewards: agent_0: 1.19 | agent_1: 1.19 | agent_2: 1.19:   0%|          | 0/1500 [53:24<?, ?it/s]
# Iter [1450/1500] | Rewards: agent_0: 1.26 | agent_1: 1.26 | agent_2: 1.26:   0%|          | 0/1500 [53:26<?, ?it/s]
# Iter [1450/1500] | Rewards: agent_0: 1.26 | agent_1: 1.26 | agent_2: 1.26:   0%|          | 0/1500 [53:26<?, ?it/s]
# Iter [1451/1500] | Rewards: agent_0: 1.22 | agent_1: 1.22 | agent_2: 1.22:   0%|          | 0/1500 [53:28<?, ?it/s]
# Iter [1451/1500] | Rewards: agent_0: 1.22 | agent_1: 1.22 | agent_2: 1.22:   0%|          | 0/1500 [53:28<?, ?it/s]
# Iter [1452/1500] | Rewards: agent_0: 1.58 | agent_1: 1.58 | agent_2: 1.58:   0%|          | 0/1500 [53:30<?, ?it/s]
# Iter [1452/1500] | Rewards: agent_0: 1.58 | agent_1: 1.58 | agent_2: 1.58:   0%|          | 0/1500 [53:30<?, ?it/s]
# Iter [1453/1500] | Rewards: agent_0: 1.51 | agent_1: 1.51 | agent_2: 1.51:   0%|          | 0/1500 [53:32<?, ?it/s]
# Iter [1453/1500] | Rewards: agent_0: 1.51 | agent_1: 1.51 | agent_2: 1.51:   0%|          | 0/1500 [53:32<?, ?it/s]
# Iter [1454/1500] | Rewards: agent_0: 1.14 | agent_1: 1.14 | agent_2: 1.14:   0%|          | 0/1500 [53:35<?, ?it/s]
# Iter [1454/1500] | Rewards: agent_0: 1.14 | agent_1: 1.14 | agent_2: 1.14:   0%|          | 0/1500 [53:35<?, ?it/s]
# Iter [1455/1500] | Rewards: agent_0: 1.14 | agent_1: 1.09 | agent_2: 1.09:   0%|          | 0/1500 [53:37<?, ?it/s]
# Iter [1455/1500] | Rewards: agent_0: 1.14 | agent_1: 1.09 | agent_2: 1.09:   0%|          | 0/1500 [53:37<?, ?it/s]
# Iter [1456/1500] | Rewards: agent_0: 1.15 | agent_1: 1.15 | agent_2: 1.15:   0%|          | 0/1500 [53:39<?, ?it/s]
# Iter [1456/1500] | Rewards: agent_0: 1.15 | agent_1: 1.15 | agent_2: 1.15:   0%|          | 0/1500 [53:39<?, ?it/s]
# Iter [1457/1500] | Rewards: agent_0: 1.15 | agent_1: 1.15 | agent_2: 1.20:   0%|          | 0/1500 [53:41<?, ?it/s]
# Iter [1457/1500] | Rewards: agent_0: 1.15 | agent_1: 1.15 | agent_2: 1.20:   0%|          | 0/1500 [53:41<?, ?it/s]
# Iter [1458/1500] | Rewards: agent_0: 1.15 | agent_1: 1.15 | agent_2: 1.15:   0%|          | 0/1500 [53:43<?, ?it/s]
# Iter [1458/1500] | Rewards: agent_0: 1.15 | agent_1: 1.15 | agent_2: 1.15:   0%|          | 0/1500 [53:43<?, ?it/s]
# Iter [1459/1500] | Rewards: agent_0: 1.10 | agent_1: 1.10 | agent_2: 1.10:   0%|          | 0/1500 [53:45<?, ?it/s]
# Iter [1459/1500] | Rewards: agent_0: 1.10 | agent_1: 1.10 | agent_2: 1.10:   0%|          | 0/1500 [53:45<?, ?it/s]
# Iter [1460/1500] | Rewards: agent_0: 0.92 | agent_1: 0.97 | agent_2: 0.92:   0%|          | 0/1500 [53:48<?, ?it/s]
# Iter [1460/1500] | Rewards: agent_0: 0.92 | agent_1: 0.97 | agent_2: 0.92:   0%|          | 0/1500 [53:48<?, ?it/s]
# Iter [1461/1500] | Rewards: agent_0: 1.51 | agent_1: 1.61 | agent_2: 1.51:   0%|          | 0/1500 [53:50<?, ?it/s]
# Iter [1461/1500] | Rewards: agent_0: 1.51 | agent_1: 1.61 | agent_2: 1.51:   0%|          | 0/1500 [53:50<?, ?it/s]
# Iter [1462/1500] | Rewards: agent_0: 1.14 | agent_1: 1.14 | agent_2: 1.14:   0%|          | 0/1500 [53:52<?, ?it/s]
# Iter [1462/1500] | Rewards: agent_0: 1.14 | agent_1: 1.14 | agent_2: 1.14:   0%|          | 0/1500 [53:52<?, ?it/s]
# Iter [1463/1500] | Rewards: agent_0: 1.37 | agent_1: 1.37 | agent_2: 1.37:   0%|          | 0/1500 [53:54<?, ?it/s]
# Iter [1463/1500] | Rewards: agent_0: 1.37 | agent_1: 1.37 | agent_2: 1.37:   0%|          | 0/1500 [53:54<?, ?it/s]
# Iter [1464/1500] | Rewards: agent_0: 0.97 | agent_1: 0.97 | agent_2: 0.97:   0%|          | 0/1500 [53:56<?, ?it/s]
# Iter [1464/1500] | Rewards: agent_0: 0.97 | agent_1: 0.97 | agent_2: 0.97:   0%|          | 0/1500 [53:56<?, ?it/s]
# Iter [1465/1500] | Rewards: agent_0: 0.88 | agent_1: 0.88 | agent_2: 0.88:   0%|          | 0/1500 [53:58<?, ?it/s]
# Iter [1465/1500] | Rewards: agent_0: 0.88 | agent_1: 0.88 | agent_2: 0.88:   0%|          | 0/1500 [53:58<?, ?it/s]
# Iter [1466/1500] | Rewards: agent_0: 1.05 | agent_1: 1.05 | agent_2: 1.05:   0%|          | 0/1500 [54:01<?, ?it/s]
# Iter [1466/1500] | Rewards: agent_0: 1.05 | agent_1: 1.05 | agent_2: 1.05:   0%|          | 0/1500 [54:01<?, ?it/s]
# Iter [1467/1500] | Rewards: agent_0: 0.95 | agent_1: 0.95 | agent_2: 0.95:   0%|          | 0/1500 [54:03<?, ?it/s]
# Iter [1467/1500] | Rewards: agent_0: 0.95 | agent_1: 0.95 | agent_2: 0.95:   0%|          | 0/1500 [54:03<?, ?it/s]
# Iter [1468/1500] | Rewards: agent_0: 1.41 | agent_1: 1.41 | agent_2: 1.41:   0%|          | 0/1500 [54:05<?, ?it/s]
# Iter [1468/1500] | Rewards: agent_0: 1.41 | agent_1: 1.41 | agent_2: 1.41:   0%|          | 0/1500 [54:05<?, ?it/s]
# Iter [1469/1500] | Rewards: agent_0: 1.11 | agent_1: 1.11 | agent_2: 1.11:   0%|          | 0/1500 [54:07<?, ?it/s]
# Iter [1469/1500] | Rewards: agent_0: 1.11 | agent_1: 1.11 | agent_2: 1.11:   0%|          | 0/1500 [54:07<?, ?it/s]
# Iter [1470/1500] | Rewards: agent_0: 1.03 | agent_1: 1.03 | agent_2: 1.03:   0%|          | 0/1500 [54:09<?, ?it/s]
# Iter [1470/1500] | Rewards: agent_0: 1.03 | agent_1: 1.03 | agent_2: 1.03:   0%|          | 0/1500 [54:09<?, ?it/s]
# Iter [1471/1500] | Rewards: agent_0: 0.74 | agent_1: 0.64 | agent_2: 0.64:   0%|          | 0/1500 [54:11<?, ?it/s]
# Iter [1471/1500] | Rewards: agent_0: 0.74 | agent_1: 0.64 | agent_2: 0.64:   0%|          | 0/1500 [54:11<?, ?it/s]
# Iter [1472/1500] | Rewards: agent_0: 0.69 | agent_1: 0.69 | agent_2: 0.69:   0%|          | 0/1500 [54:14<?, ?it/s]
# Iter [1472/1500] | Rewards: agent_0: 0.69 | agent_1: 0.69 | agent_2: 0.69:   0%|          | 0/1500 [54:14<?, ?it/s]
# Iter [1473/1500] | Rewards: agent_0: 0.99 | agent_1: 0.99 | agent_2: 0.99:   0%|          | 0/1500 [54:16<?, ?it/s]
# Iter [1473/1500] | Rewards: agent_0: 0.99 | agent_1: 0.99 | agent_2: 0.99:   0%|          | 0/1500 [54:16<?, ?it/s]
# Iter [1474/1500] | Rewards: agent_0: 0.92 | agent_1: 0.97 | agent_2: 0.92:   0%|          | 0/1500 [54:18<?, ?it/s]
# Iter [1474/1500] | Rewards: agent_0: 0.92 | agent_1: 0.97 | agent_2: 0.92:   0%|          | 0/1500 [54:18<?, ?it/s]
# Iter [1475/1500] | Rewards: agent_0: 0.83 | agent_1: 0.83 | agent_2: 0.83:   0%|          | 0/1500 [54:20<?, ?it/s]
# Iter [1475/1500] | Rewards: agent_0: 0.83 | agent_1: 0.83 | agent_2: 0.83:   0%|          | 0/1500 [54:20<?, ?it/s]
# Iter [1476/1500] | Rewards: agent_0: 1.04 | agent_1: 0.99 | agent_2: 0.99:   0%|          | 0/1500 [54:22<?, ?it/s]
# Iter [1476/1500] | Rewards: agent_0: 1.04 | agent_1: 0.99 | agent_2: 0.99:   0%|          | 0/1500 [54:22<?, ?it/s]
# Iter [1477/1500] | Rewards: agent_0: 0.94 | agent_1: 0.94 | agent_2: 0.94:   0%|          | 0/1500 [54:24<?, ?it/s]
# Iter [1477/1500] | Rewards: agent_0: 0.94 | agent_1: 0.94 | agent_2: 0.94:   0%|          | 0/1500 [54:24<?, ?it/s]
# Iter [1478/1500] | Rewards: agent_0: 1.16 | agent_1: 1.16 | agent_2: 1.16:   0%|          | 0/1500 [54:27<?, ?it/s]
# Iter [1478/1500] | Rewards: agent_0: 1.16 | agent_1: 1.16 | agent_2: 1.16:   0%|          | 0/1500 [54:27<?, ?it/s]
# Iter [1479/1500] | Rewards: agent_0: 0.54 | agent_1: 0.54 | agent_2: 0.54:   0%|          | 0/1500 [54:29<?, ?it/s]
# Iter [1479/1500] | Rewards: agent_0: 0.54 | agent_1: 0.54 | agent_2: 0.54:   0%|          | 0/1500 [54:29<?, ?it/s]
# Iter [1480/1500] | Rewards: agent_0: 1.08 | agent_1: 1.08 | agent_2: 1.08:   0%|          | 0/1500 [54:31<?, ?it/s]
# Iter [1480/1500] | Rewards: agent_0: 1.08 | agent_1: 1.08 | agent_2: 1.08:   0%|          | 0/1500 [54:31<?, ?it/s]
# Iter [1481/1500] | Rewards: agent_0: 0.94 | agent_1: 0.94 | agent_2: 0.94:   0%|          | 0/1500 [54:33<?, ?it/s]
# Iter [1481/1500] | Rewards: agent_0: 0.94 | agent_1: 0.94 | agent_2: 0.94:   0%|          | 0/1500 [54:33<?, ?it/s]
# Iter [1482/1500] | Rewards: agent_0: 0.99 | agent_1: 0.99 | agent_2: 0.99:   0%|          | 0/1500 [54:35<?, ?it/s]
# Iter [1482/1500] | Rewards: agent_0: 0.99 | agent_1: 0.99 | agent_2: 0.99:   0%|          | 0/1500 [54:35<?, ?it/s]
# Iter [1483/1500] | Rewards: agent_0: 0.66 | agent_1: 0.66 | agent_2: 0.66:   0%|          | 0/1500 [54:37<?, ?it/s]
# Iter [1483/1500] | Rewards: agent_0: 0.66 | agent_1: 0.66 | agent_2: 0.66:   0%|          | 0/1500 [54:37<?, ?it/s]
# Iter [1484/1500] | Rewards: agent_0: 0.94 | agent_1: 0.89 | agent_2: 0.89:   0%|          | 0/1500 [54:40<?, ?it/s]
# Iter [1484/1500] | Rewards: agent_0: 0.94 | agent_1: 0.89 | agent_2: 0.89:   0%|          | 0/1500 [54:40<?, ?it/s]
# Iter [1485/1500] | Rewards: agent_0: 0.49 | agent_1: 0.54 | agent_2: 0.49:   0%|          | 0/1500 [54:42<?, ?it/s]
# Iter [1485/1500] | Rewards: agent_0: 0.49 | agent_1: 0.54 | agent_2: 0.49:   0%|          | 0/1500 [54:42<?, ?it/s]
# Iter [1486/1500] | Rewards: agent_0: 0.46 | agent_1: 0.46 | agent_2: 0.46:   0%|          | 0/1500 [54:44<?, ?it/s]
# Iter [1486/1500] | Rewards: agent_0: 0.46 | agent_1: 0.46 | agent_2: 0.46:   0%|          | 0/1500 [54:44<?, ?it/s]
# Iter [1487/1500] | Rewards: agent_0: 1.06 | agent_1: 1.06 | agent_2: 1.06:   0%|          | 0/1500 [54:46<?, ?it/s]
# Iter [1487/1500] | Rewards: agent_0: 1.06 | agent_1: 1.06 | agent_2: 1.06:   0%|          | 0/1500 [54:46<?, ?it/s]
# Iter [1488/1500] | Rewards: agent_0: 0.64 | agent_1: 0.64 | agent_2: 0.64:   0%|          | 0/1500 [54:48<?, ?it/s]
# Iter [1488/1500] | Rewards: agent_0: 0.64 | agent_1: 0.64 | agent_2: 0.64:   0%|          | 0/1500 [54:48<?, ?it/s]
# Iter [1489/1500] | Rewards: agent_0: 1.02 | agent_1: 1.02 | agent_2: 1.02:   0%|          | 0/1500 [54:50<?, ?it/s]
# Iter [1489/1500] | Rewards: agent_0: 1.02 | agent_1: 1.02 | agent_2: 1.02:   0%|          | 0/1500 [54:50<?, ?it/s]
# Iter [1490/1500] | Rewards: agent_0: 0.76 | agent_1: 0.76 | agent_2: 0.76:   0%|          | 0/1500 [54:53<?, ?it/s]
# Iter [1490/1500] | Rewards: agent_0: 0.76 | agent_1: 0.76 | agent_2: 0.76:   0%|          | 0/1500 [54:53<?, ?it/s]
# Iter [1491/1500] | Rewards: agent_0: 1.07 | agent_1: 1.07 | agent_2: 1.07:   0%|          | 0/1500 [54:55<?, ?it/s]
# Iter [1491/1500] | Rewards: agent_0: 1.07 | agent_1: 1.07 | agent_2: 1.07:   0%|          | 0/1500 [54:55<?, ?it/s]
# Iter [1492/1500] | Rewards: agent_0: 1.21 | agent_1: 1.21 | agent_2: 1.21:   0%|          | 0/1500 [54:57<?, ?it/s]
# Iter [1492/1500] | Rewards: agent_0: 1.21 | agent_1: 1.21 | agent_2: 1.21:   0%|          | 0/1500 [54:57<?, ?it/s]
# Iter [1493/1500] | Rewards: agent_0: 0.85 | agent_1: 0.90 | agent_2: 0.85:   0%|          | 0/1500 [54:59<?, ?it/s]
# Iter [1493/1500] | Rewards: agent_0: 0.85 | agent_1: 0.90 | agent_2: 0.85:   0%|          | 0/1500 [54:59<?, ?it/s]
# Iter [1494/1500] | Rewards: agent_0: 0.78 | agent_1: 0.78 | agent_2: 0.78:   0%|          | 0/1500 [55:01<?, ?it/s]
# Iter [1494/1500] | Rewards: agent_0: 0.78 | agent_1: 0.78 | agent_2: 0.78:   0%|          | 0/1500 [55:01<?, ?it/s]
# Iter [1495/1500] | Rewards: agent_0: 0.72 | agent_1: 0.72 | agent_2: 0.72:   0%|          | 0/1500 [55:03<?, ?it/s]
# Iter [1495/1500] | Rewards: agent_0: 0.72 | agent_1: 0.72 | agent_2: 0.72:   0%|          | 0/1500 [55:03<?, ?it/s]
# Iter [1496/1500] | Rewards: agent_0: 0.64 | agent_1: 0.69 | agent_2: 0.64:   0%|          | 0/1500 [55:06<?, ?it/s]
# Iter [1496/1500] | Rewards: agent_0: 0.64 | agent_1: 0.69 | agent_2: 0.64:   0%|          | 0/1500 [55:06<?, ?it/s]
# Iter [1497/1500] | Rewards: agent_0: 1.00 | agent_1: 1.00 | agent_2: 1.00:   0%|          | 0/1500 [55:08<?, ?it/s]
# Iter [1497/1500] | Rewards: agent_0: 1.00 | agent_1: 1.00 | agent_2: 1.00:   0%|          | 0/1500 [55:08<?, ?it/s]
# Iter [1498/1500] | Rewards: agent_0: 0.79 | agent_1: 0.79 | agent_2: 0.79:   0%|          | 0/1500 [55:10<?, ?it/s]
# Iter [1498/1500] | Rewards: agent_0: 0.79 | agent_1: 0.79 | agent_2: 0.79:   0%|          | 0/1500 [55:10<?, ?it/s]
# Iter [1499/1500] | Rewards: agent_0: 0.81 | agent_1: 0.81 | agent_2: 0.81:   0%|          | 0/1500 [55:12<?, ?it/s]
# Iter [1499/1500] | Rewards: agent_0: 0.81 | agent_1: 0.81 | agent_2: 0.81:   0%|          | 0/1500 [55:12<?, ?it/s]
# Iter [1500/1500] | Rewards: agent_0: 0.87 | agent_1: 0.77 | agent_2: 0.77:   0%|          | 0/1500 [55:14<?, ?it/s]
# Iter [1500/1500] | Rewards: agent_0: 0.87 | agent_1: 0.77 | agent_2: 0.77:   0%|          | 0/1500 [55:14<?, ?it/s]
# Training finished.

# %% [markdown]
# ##Plotting Results

# %%
fig, axs = plt.subplots(n_agents, 1, figsize=(10, 8), sharex=True)
if n_agents == 1:
    axs = [axs]
for i, group in enumerate(env.group_map.keys()):
    axs[i].plot(episode_reward_mean_map[group], label=f"Episode reward mean {group}")
    axs[i].set_ylabel("Reward")
    axs[i].legend()
axs[-1].set_xlabel("Training iterations")
fig.suptitle("Training Rewards")
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ##Evaluation and Rendering

# %%
print("Starting evaluation and rendering...")

# Create a single environment for rendering
render_env = VmasEnv(
    scenario=scenario_name,
    num_envs=1,
    continuous_actions=True,
    max_steps=max_steps,
    device=device,
    n_agents=n_agents,
    group_map=custom_group_map,
)

td = render_env.reset()
frames = []

# Rollout Loop
with torch.no_grad():
    for _ in range(max_steps):
        # 1. Run policies to get actions
        for group in render_env.group_map.keys():
            td = policies[group](td)

        # 2. Step the environment
        td_next = render_env.step(td)

        # 3. Use the new observation for the next policy call
        td = td_next.get("next").clone()

        # 4. Reset if the episode terminated
        if td_next.get("done").item():
            td = render_env.reset()

        # 5. Render the frame and append to list
        frame = render_env.render(mode="rgb_array")
        frames.append(Image.fromarray(frame))

# Save the rollout as a GIF
gif_path = f"{scenario_name}_evaluation.gif"
frames[0].save(
    gif_path,
    save_all=True,
    append_images=frames[1:],
    duration=100,
    loop=0,
)
print(f"✅ Saved animation as {gif_path}")

# To display the GIF in a Jupyter notebook, you can use the following:
# from IPython.display import Image as IPImage
# IPImage(filename=gif_path)
# Out:
# Starting evaluation and rendering...
# ✅ Saved animation as navigation_evaluation.gif

# %%
from IPython.display import Image as IPImage
IPImage(filename=gif_path)

# %% [markdown]
# ##Part 4
#
# Based on your understanding of the differences between MADDPG and IDDPG, modify the necessary sections of your MADDPG implementation to convert it into its independent variant (IDDPG). Run the modified code, clearly explain the changes you made and the rationale behind each modification, and finally analyze and discuss the differences you observe between the performance of MADDPG and IDDPG.
